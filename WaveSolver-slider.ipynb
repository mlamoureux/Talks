# %% [markdown]
# # WaveSolver - slider
# M. Lamoureux May 31, 2016. Pacific Insitute for the Mathematical Sciences
#
# This code does some numerical simulation of wave propagation in 1D, suitable for demoing in a class.
#
# This is a rewrite of some of my old Julia code, translated to run in Python. My belief is that Python is a more mature system and I will likely be more productive by sticking to Python instead of Julia. Let's see if this is true.
#
# The code is based on formulas from the textbook Linear Partial Differential Equations for Scientists and Engineers, by Myint-U and Debnath. It's a good book -- you should buy it. Some extracts are also available online.
#
# In this Jupyter notebook, animation has been added, using GUI sliders to advance the waveform in time.
#
#
# This was also written as a test of how far we can push Bokeh and the Jupyter Hub in making some calculations and graphics. There is some dangerous code at the bottom, that can bring down our Jupyter Hub, probably because it eats up too much memory. Interesting for debugging purposes, but you have been warned.

# %% [markdown]
# ## Introduction to the 1D wave equation.
#
# The basic idea is to represent the vibrations of a (horizonal) string under tension by a function $u(x,t)$ where $x$ is the horizontal displacement along the string, $t$ is the time parameter, and $y=u(x,t)$ indicates the (vertical) displacement of the string at point $x$ along the string, at time $t$
#
# A typical wave would look something like
# $$u(x,t) = \sin(x-ct)$$
# which represents a sinusoidal wave moving to the right at velocity $c$.
#
# From Newon's law of motion (mass times acceleration equals force), we can derive the wave equation for the string in the form
# $$ \rho \cdot u_{tt} = k \cdot u_{xx}$$
# where $\rho$ is a mass density, $u_{tt}$ is an acceleration (the second derivative w.r.t. time), $k$ is the modulus of elasticity and $u_{xx}$ is a measure of curvature (the second derivative w.r.t. $x$), causing the bending force.
#
# Including boundary and initial conditions, while setting the parameter $c^2 = k/\rho$, we obtain the usual 1D wave equation on an interval as this:
#
#
# $$u_{tt} = c^2 u_{xx} \mbox{ on interval } [x_0,x_1]$$
# subject to boundary conditions
# $$u(x_0,t) = u(x_1, t) = 0 \mbox{ for all $t$. }$$
# and initial conditions
# $$u(x,0) = u_0(x), \quad u_t(x,t) = u_1(x) \mbox{ on interval } [x_0,x_1].$$
#
#
# Let's write some PDE solvers for this 1D wave equation.
#
# Start with some simple solvers, then get more complex.
#
# The function to solve the PDE needs to know $c^2, u_0, u_1$, the sampling intervals $dx$ and $dt$, and the number of time steps to execute. Everything else can be inferred from those inputs. The output should be a 2D array, indexed in x and t steps.
#
# Maybe we could actually output the solution $u(x,t)$ as well as the vector of indices for $x$ and $t$.

# %% [markdown]
# ## Software tools
# We import some tools for numerical work (NumPy) and plotting (Boken), using Boken because it is faster than matplotlib).

# %%
from bokeh.models import ColumnDataSource
from bokeh.plotting import *
from bokeh.io import push_notebook
import numpy as np

# %% [markdown]
# We also include some code from SciPy for numerical calculations

# %%
from scipy.linalg import solve_toeplitz  # a matrix equation solver
from scipy.integrate import cumtrapz # a numerical integrator, using trapezoid rule

# %% [markdown]
# And we include some code to create the graphical user interface -- namely, sliders. You can read about them here:
# http://bokeh.pydata.org/en/0.10.0/_images/notebook_interactors.png

# %%
from ipywidgets import interact

# %% [markdown]
# ## Explicit method of solution in finite differences
#
# The finite difference method is probably the most common numerical method for solving PDEs. The derivatives are approximated by Newton difference ratios, and you step through in time to progress the solution from $t=0$ to some ending time.
#
# The following defines a function that solves the wave equation, using an explicit finite difference method. We follow the notes in the referenced book by Myint-U and Debnath.
#
# The differencing in spatial variable $x$ is done by a convolution, as this will be fast.
#
# We print out the value of the CFL constant as a sanity check. The method is stable and convergent provided the CFL value is less than one. (This means $dt$ needs to be small enough.) See the book for details.
#
# The input parameters are velocity squared $c2$, spatial step size $dx$, temporal step size $dt$, number of time steps $t$_$len$, initial position $u0$ and initial velocity $u1$. $u0$ and $u1$ are arrays of some length $N$, which the code will use to deduce everything it needs to know.
#
# I tend to think of these as dimensionless variables, but you can use real physical values if you like, so long as you are consistent. For instance $dx$ in meters, $dt$ in seconds, and $c2$ in (meters/second) squared.

# %%
# Based on Section 14.4 in Myint-U and Debnath's book
def w_solve1(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    e2 = c2*dt*dt/(dx*dx)  # Courant parameter squared (test for convergence!)
    print("CFL value is ",np.sqrt(e2))
    kern = np.array([e2, 2*(1-e2), e2]) # the convolution kernel we need for laplacian solver
    u[:,0] = u0            # t=0 initial condition
    u[:,1] = np.convolve(u0,kern/2)[1:x_len+1] + dt*u1 # t=0 derivative condition, eqn 14.4.6
    for j in range(2,t_len):
        u[:,j] = np.convolve(u[:,j-1],kern)[1:x_len+1] - u[:,j-2] # eqn 14.4.3
    # let's produce the x and t vectors, in case we need them
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    return u,x,t

# %% [markdown]
# Let's try a real wave equation solution.
#
# We start with a simple triangle waveform.

# %%
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# %% [markdown]
# Now we call up our wave equation solver, using the parameters above

# %%
# Here we solve the wave equation, with initial position $u(x,0)$ set to the triangle waveform
(u,x,t)=w_solve1(.5,dx,dt,t_len,triangle,0*triangle)
# Out:
# CFL value is  0.707106781187

# %% [markdown]
# We initialize the plotting tools in Bokeh and plot the initial waveform.

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="844a1f91-d85e-4314-a1f7-5797ce99e301">Loading BokehJS ...</span>
#     </div>

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="F.D. Explicit method solution", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()

show(p)
# Out:
#     <div class="plotdiv" id="049be288-ec40-4595-bd71-d9a628bfed78"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("049be288-ec40-4595-bd71-d9a628bfed78");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '049be288-ec40-4595-bd71-d9a628bfed78' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"93adc19c-82e8-49a2-8bd4-d17991bd263a":{"roots":{"references":[{"attributes":{},"id":"a58bd9df-d088-4306-ad56-713a46174e2b","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cce75894-3760-4c4b-9e87-d8023adfd4ae","type":"BoxAnnotation"},{"attributes":{},"id":"9bde7dc6-22c1-46dd-8d6d-163809468fbb","type":"BasicTicker"},{"attributes":{"formatter":{"id":"a58bd9df-d088-4306-ad56-713a46174e2b","type":"BasicTickFormatter"},"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"},"ticker":{"id":"9bde7dc6-22c1-46dd-8d6d-163809468fbb","type":"BasicTicker"}},"id":"3ab5bf88-9f84-4170-9bd8-dab6c873c0bc","type":"LinearAxis"},{"attributes":{},"id":"a514e15a-3903-4a00-ba35-965becb474b1","type":"ToolEvents"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"17674402-cc6d-4e05-99d4-bb6f5aca8a34","type":"HelpTool"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"72395f86-db3f-4847-912d-1abba7c0a823","type":"ResizeTool"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"c76b3c6a-992d-4a39-92a2-9f855ee97065","type":"PanTool"},{"attributes":{"callback":null},"id":"65c6594c-db8c-44a7-a890-13a8bcd559ec","type":"DataRange1d"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"91fc0baf-6937-465d-bfff-c5c5c88daf5d","type":"PreviewSaveTool"},{"attributes":{},"id":"93e99206-8c0e-4e6c-b42a-f75bdd030a96","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"},"ticker":{"id":"9bde7dc6-22c1-46dd-8d6d-163809468fbb","type":"BasicTicker"}},"id":"6681ddaa-2af7-4057-81ee-b809b60a82ca","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011,0.012,0.013000000000000001,0.014,0.015,0.016,0.017,0.018000000000000002,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026000000000000002,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036000000000000004,0.037,0.038,0.039,0.04,0.041,0.042,0.043000000000000003,0.044,0.045,0.046,0.047,0.048,0.049,0.05,0.051000000000000004,0.052000000000000005,0.053,0.054,0.055,0.056,0.057,0.058,0.059000000000000004,0.06,0.061,0.062,0.063,0.064,0.065,0.066,0.067,0.068,0.069,0.07,0.07100000000000001,0.07200000000000001,0.073,0.074,0.075,0.076,0.077,0.078,0.079,0.08,0.081,0.082,0.083,0.084,0.085,0.08600000000000001,0.08700000000000001,0.088,0.089,0.09,0.091,0.092,0.093,0.094,0.095,0.096,0.097,0.098,0.099,0.1,0.101,0.10200000000000001,0.10300000000000001,0.10400000000000001,0.105,0.106,0.107,0.108,0.109,0.11,0.111,0.112,0.113,0.114,0.115,0.116,0.117,0.11800000000000001,0.11900000000000001,0.12,0.121,0.122,0.123,0.124,0.125,0.126,0.127,0.128,0.129,0.13,0.131,0.132,0.133,0.134,0.135,0.136,0.137,0.138,0.139,0.14,0.14100000000000001,0.14200000000000002,0.14300000000000002,0.14400000000000002,0.145,0.146,0.147,0.148,0.149,0.15,0.151,0.152,0.153,0.154,0.155,0.156,0.157,0.158,0.159,0.16,0.161,0.162,0.163,0.164,0.165,0.166,0.167,0.168,0.169,0.17,0.171,0.17200000000000001,0.17300000000000001,0.17400000000000002,0.17500000000000002,0.176,0.177,0.178,0.179,0.18,0.181,0.182,0.183,0.184,0.185,0.186,0.187,0.188,0.189,0.19,0.191,0.192,0.193,0.194,0.195,0.196,0.197,0.198,0.199,0.2,0.201,0.202,0.203,0.20400000000000001,0.20500000000000002,0.20600000000000002,0.20700000000000002,0.20800000000000002,0.209,0.21,0.211,0.212,0.213,0.214,0.215,0.216,0.217,0.218,0.219,0.22,0.221,0.222,0.223 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %% [markdown]
# And the next cell sets up a slider which controls the above graphs (it moves time along)

# %%
# This runs an animation, controlled by a slider which advances time
interact(update,k=(0,t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# ### Derivative initial condition test

# %%
# We try again, but this time with the $u_t$ initial condition equal to the triangle impulse
(u,x,t)=w_solve1(.5,dx,dt,3*t_len,0*triangle,1*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="F.D. Explicit method solution, Der Cond", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="46481f96-89f8-4b4e-b527-0060602daf15"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("46481f96-89f8-4b4e-b527-0060602daf15");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '46481f96-89f8-4b4e-b527-0060602daf15' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c6ddf944-9d05-4f77-a019-d4a80d1dc57e":{"roots":{"references":[{"attributes":{},"id":"9bde7dc6-22c1-46dd-8d6d-163809468fbb","type":"BasicTicker"},{"attributes":{"formatter":{"id":"a58bd9df-d088-4306-ad56-713a46174e2b","type":"BasicTickFormatter"},"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"},"ticker":{"id":"9bde7dc6-22c1-46dd-8d6d-163809468fbb","type":"BasicTicker"}},"id":"3ab5bf88-9f84-4170-9bd8-dab6c873c0bc","type":"LinearAxis"},{"attributes":{},"id":"a514e15a-3903-4a00-ba35-965becb474b1","type":"ToolEvents"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"17674402-cc6d-4e05-99d4-bb6f5aca8a34","type":"HelpTool"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"72395f86-db3f-4847-912d-1abba7c0a823","type":"ResizeTool"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"c76b3c6a-992d-4a39-92a2-9f855ee97065","type":"PanTool"},{"attributes":{"callback":null},"id":"65c6594c-db8c-44a7-a890-13a8bcd559ec","type":"DataRange1d"},{"attributes":{"overlay":{"id":"453ba279-7fbc-45fd-a15b-5bd547f83c95","type":"BoxAnnotation"},"plot":{"id":"8f2fd910-5049-4770-b11a-c1221ac6dda8","subtype":"Figure","type":"Plot"}},"id":"d46f9553-8557-4273-88a0-1b5094408b4f","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"91fc0baf-6937-465d-bfff-c5c5c88daf5d","type":"PreviewSaveTool"},{"attributes":{"formatter":{"id":"e5a81b3a-39bb-4a1e-afb1-432643183fd7","type":"BasicTickFormatter"},"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"},"ticker":{"id":"93e99206-8c0e-4e6c-b42a-f75bdd030a96","type":"BasicTicker"}},"id":"12eb322b-b203-4589-80e6-ea9d2e95b88f","type":"LinearAxis"},{"attributes":{"plot":{"id":"8f2fd910-5049-4770-b11a-c1221ac6dda8","subtype":"Figure","type":"Plot"}},"id":"528e72be-7eda-4529-95ae-50ea54e0958e","type":"ResizeTool"},{"attributes":{"data_source":{"id":"fb577899-414e-4509-b540-f726f4c0331b","type":"ColumnDataSource"},"glyph":{"id":"b92c98c6-6be2-4129-9f83-5e3c2cf4974d","type":"Line"},"hover_glyph":null,"name":"foo","nonselection_glyph":{"id":"e6cde027-ac7d-4230-bba5-5279dfc2747f","type":"Line"},"selection_glyph":null},"id":"f34a3667-87b0-46cd-81f9-f23c65fe213a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8f2fd910-5049-4770-b11a-c1221ac6dda8","subtype":"Figure","type":"Plot"}},"id":"9b853346-1e85-4157-850b-abd3f2ef3d20","type":"PanTool"},{"attributes":{"plot":{"id":"8f2fd910-5049-4770-b11a-c1221ac6dda8","subtype":"Figure","type":"Plot"}},"id":"f9abbfc2-d2c6-4dd2-a214-51a417f9d6a0","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"cf03c425-41c4-45a0-92f6-6e7b9d1c95f3","type":"BasicTickFormatter"},"plot":{"id":"8f2fd910-5049-4770-b11a-c1221ac6dda8","subtype":"Figure","type":"Plot"},"ticker":{"id":"d0f5afaf-bc4f-46ec-8666-1d10e4896726","type":"BasicTicker"}},"id":"8b0e334c-3133-4d2b-af22-2f00c668712c","type":"LinearAxis"},{"attributes":{"callback":null},"id":"f6b457eb-a232-4a7d-8715-c584e3f0e1c3","type":"DataRange1d"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"6dbae2ce-c794-4c84-b550-f14de5da3feb","type":"WheelZoomTool"},{"attributes":{},"id":"de6992cd-c58a-4af9-b731-b9325623d1cb","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"0efe3795-7f14-4f2a-b40a-5383135f81ff","type":"Line"},{"attributes":{},"id":"e5a81b3a-39bb-4a1e-afb1-432643183fd7","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e6cde027-ac7d-4230-bba5-5279dfc2747f","type":"Line"},{"attributes":{},"id":"6abd8 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>

# %%
interact(update,k=(0,3*t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# ## Implicit method
#
# Here we try an implicit method for solving the wave equation. Again from Myint-U and Debnath's book, in Section 14.5, part (B) on Hyperbolic equations.
#
# We need to use scipy libraries as we have to solve a system of linear equation. In fact the system is tridiagonal and Toepliz, so this should be fast. I see how to use Toepliz in scipy, but I don't know how to tell it that the system is only tridiagonal. It should be possible to speed this up.

# %%
# Based on Section 14.5 (B) in Myint-U and Debnath's book
def w_solve2(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    e2 = c2*dt*dt/(dx*dx)  # Courant parameter squared (test for convergence!)
    print("CFL value is ",np.sqrt(e2))
    kern = np.array([e2, 2*(1-e2), e2]) # the convolution kernel we need for laplacian solver
    u[:,0] = u0            # t=0 initial condition
    u[:,1] = np.convolve(u0,kern/2)[1:x_len+1] + dt*u1 # t=0 derivative condition, eqn 14.4.6
    # Note the above is a cheat, we are using the explicit method to find u[:,1], Should do this implicitly
    kern2 = np.array([e2, -2*(1+e2), e2]) # the convolution kernel we need for implicit solver. It is different.
    toepk = np.zeros(x_len)  # this will hold the entries for the tridiagonal Toeplitz matrix
    toepk[0] = 2*(1+e2);
    toepk[1] = -e2
    for j in range(2,t_len):
        rhs = np.convolve(u[:,j-2],kern2)[1:x_len+1] + 4*u[:,j-1] # eqn 14.5.17
        u[:,j] = solve_toeplitz(toepk, rhs) # here is a linear system solver (hence an implicit method)
    # let's produce the x and t vectors, in case we need them
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    return u,x,t

# %%
(u,x,t)=w_solve2(.5,dx,dt,t_len,1*triangle,0*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="Implicit solution method", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="5c423470-783e-4d75-8705-5bf6cc74ca80"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5c423470-783e-4d75-8705-5bf6cc74ca80");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5c423470-783e-4d75-8705-5bf6cc74ca80' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c80546ba-0efe-4e61-a3a0-292f4f2da9ef":{"roots":{"references":[{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"72395f86-db3f-4847-912d-1abba7c0a823","type":"ResizeTool"},{"attributes":{},"id":"9bde7dc6-22c1-46dd-8d6d-163809468fbb","type":"BasicTicker"},{"attributes":{"formatter":{"id":"a58bd9df-d088-4306-ad56-713a46174e2b","type":"BasicTickFormatter"},"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"},"ticker":{"id":"9bde7dc6-22c1-46dd-8d6d-163809468fbb","type":"BasicTicker"}},"id":"3ab5bf88-9f84-4170-9bd8-dab6c873c0bc","type":"LinearAxis"},{"attributes":{},"id":"a514e15a-3903-4a00-ba35-965becb474b1","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9646cbb1-bcd6-4d46-a6a1-958fdc60b56d","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"17674402-cc6d-4e05-99d4-bb6f5aca8a34","type":"HelpTool"},{"attributes":{},"id":"d0f5afaf-bc4f-46ec-8666-1d10e4896726","type":"BasicTicker"},{"attributes":{"callback":null},"id":"a69bee60-04e2-4a0e-a376-cfe01331850c","type":"DataRange1d"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"c76b3c6a-992d-4a39-92a2-9f855ee97065","type":"PanTool"},{"attributes":{"callback":null},"id":"65c6594c-db8c-44a7-a890-13a8bcd559ec","type":"DataRange1d"},{"attributes":{"overlay":{"id":"9646cbb1-bcd6-4d46-a6a1-958fdc60b56d","type":"BoxAnnotation"},"plot":{"id":"ef08fd42-541b-4119-90ce-4af8ac911799","subtype":"Figure","type":"Plot"}},"id":"1f0a538f-6f09-485c-8b0d-1242f26eb958","type":"BoxZoomTool"},{"attributes":{"overlay":{"id":"453ba279-7fbc-45fd-a15b-5bd547f83c95","type":"BoxAnnotation"},"plot":{"id":"8f2fd910-5049-4770-b11a-c1221ac6dda8","subtype":"Figure","type":"Plot"}},"id":"d46f9553-8557-4273-88a0-1b5094408b4f","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"ef08fd42-541b-4119-90ce-4af8ac911799","subtype":"Figure","type":"Plot"}},"id":"f7ec6c26-48ca-406c-91a4-45a1cc73d373","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"91fc0baf-6937-465d-bfff-c5c5c88daf5d","type":"PreviewSaveTool"},{"attributes":{"formatter":{"id":"e5a81b3a-39bb-4a1e-afb1-432643183fd7","type":"BasicTickFormatter"},"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"},"ticker":{"id":"93e99206-8c0e-4e6c-b42a-f75bdd030a96","type":"BasicTicker"}},"id":"12eb322b-b203-4589-80e6-ea9d2e95b88f","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"24f7632f-4e78-49d6-8b70-71b380bf9312","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011,0.012,0.013000000000000001,0.014,0.015,0.016,0.017,0.018000000000000002,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026000000000000002,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036000000000000004,0.037,0.038,0.039,0.04,0.041,0.042,0.043000000000000003,0.044,0.045,0.046,0.047,0.048,0.049,0.05,0.051000000000000004,0.052000000000000005,0.053,0.054,0.055,0.056,0.057,0.058,0.059000000000000004,0.06,0.061,0.062,0.063,0.064,0.065,0.066,0.067,0.068,0.069,0.07,0.07100000000000001,0.07200000000000001,0.073,0.074,0.075,0.076,0.077,0.078,0.079,0.08,0.081,0.082,0.083,0.084,0.085,0.08600000000000001,0.08700000000000001,0.088,0.089,0.09,0.091,0.092,0.093,0.094,0.095,0.096,0.097,0.098,0.099,0.1,0.101,0.10200000000000001,0.10300000000000001,0.104000000 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[15]</strong>&gt;</code></p>

# %%
interact(update,k=(0,3*t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# ### Derivative initial condition

# %%
(u,x,t)=w_solve2(.5,dx,dt,3*t_len,0*triangle,1*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="Implicit solution method, Der cond", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="a1d80b76-4658-4fb4-878f-d3793b78b082"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a1d80b76-4658-4fb4-878f-d3793b78b082");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a1d80b76-4658-4fb4-878f-d3793b78b082' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"0cda8ccc-79f8-44d1-a3d2-4527b5c0efae":{"roots":{"references":[{"attributes":{},"id":"9bde7dc6-22c1-46dd-8d6d-163809468fbb","type":"BasicTicker"},{"attributes":{},"id":"8f1190cd-2896-4ab6-a478-44f853d0b53a","type":"BasicTicker"},{"attributes":{},"id":"a514e15a-3903-4a00-ba35-965becb474b1","type":"ToolEvents"},{"attributes":{"formatter":{"id":"27950741-3c83-4e44-9cda-f95b13dcbec1","type":"BasicTickFormatter"},"plot":{"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"},"ticker":{"id":"8f1190cd-2896-4ab6-a478-44f853d0b53a","type":"BasicTicker"}},"id":"43afce8b-3aac-4df3-92ae-278b389c0ad5","type":"LinearAxis"},{"attributes":{"formatter":{"id":"db52d801-e4b1-408a-8fca-c55e2b14f560","type":"BasicTickFormatter"},"plot":{"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"},"ticker":{"id":"3f961d97-e53b-4c23-afca-11e446237d41","type":"BasicTicker"}},"id":"1d06d448-90dd-41dc-bf52-1aafdf4629ee","type":"LinearAxis"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"c76b3c6a-992d-4a39-92a2-9f855ee97065","type":"PanTool"},{"attributes":{"callback":null},"id":"65c6594c-db8c-44a7-a890-13a8bcd559ec","type":"DataRange1d"},{"attributes":{"plot":{"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"}},"id":"edca2512-13f1-4497-bad6-c1ec67cc4284","type":"PreviewSaveTool"},{"attributes":{"plot":{"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"}},"id":"3ed89648-cf02-40f7-a89f-3f375c2d42c0","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"91fc0baf-6937-465d-bfff-c5c5c88daf5d","type":"PreviewSaveTool"},{"attributes":{"plot":{"id":"8f2fd910-5049-4770-b11a-c1221ac6dda8","subtype":"Figure","type":"Plot"}},"id":"528e72be-7eda-4529-95ae-50ea54e0958e","type":"ResizeTool"},{"attributes":{"data_source":{"id":"fb577899-414e-4509-b540-f726f4c0331b","type":"ColumnDataSource"},"glyph":{"id":"b92c98c6-6be2-4129-9f83-5e3c2cf4974d","type":"Line"},"hover_glyph":null,"name":"foo","nonselection_glyph":{"id":"e6cde027-ac7d-4230-bba5-5279dfc2747f","type":"Line"},"selection_glyph":null},"id":"f34a3667-87b0-46cd-81f9-f23c65fe213a","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"cf03c425-41c4-45a0-92f6-6e7b9d1c95f3","type":"BasicTickFormatter"},"plot":{"id":"8f2fd910-5049-4770-b11a-c1221ac6dda8","subtype":"Figure","type":"Plot"},"ticker":{"id":"d0f5afaf-bc4f-46ec-8666-1d10e4896726","type":"BasicTicker"}},"id":"8b0e334c-3133-4d2b-af22-2f00c668712c","type":"LinearAxis"},{"attributes":{"data_source":{"id":"97b04569-2733-4c96-9b64-6fbcf943acb9","type":"ColumnDataSource"},"glyph":{"id":"904aea90-086f-434d-b657-7c49161f12ae","type":"Line"},"hover_glyph":null,"name":"foo","nonselection_glyph":{"id":"c1aae3ea-2f85-4906-a4fa-4695686b889e","type":"Line"},"selection_glyph":null},"id":"b7813175-a02d-47ab-a902-eb10c3dd80a1","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"8f2fd910-5049-4770-b11a-c1221ac6dda8","subtype":"Figure","type":"Plot"},"ticker":{"id":"6abd83cc-ede2-4c2a-9535-08d3b6c91e13","type":"BasicTicker"}},"id":"60c8144b-c753-4808-a451-e430d6378181","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"0efe3795-7f14-4f2a-b40a-5383135f81ff","type":"Line"},{"attributes":{},"id":"e5a81b3a-39bb-4a1e-afb1-432643183fd7","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e6cde027-ac7d-4230-bba5-5279dfc2747f","type":"Line"},{"attributes":{"below":[{"id":"1d06d448-90dd-41dc-bf52-1aafdf4629ee","type":"LinearAxis"}],"left":[{"id":"43afce8b-3aac-4df3-92ae-278b389c0ad5","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"1d06d448-90dd-41dc-bf52-1aafdf4629ee","type": ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[18]</strong>&gt;</code></p>

# %%
interact(update,k=(0,3*t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# ## D'Alembert's solution
#
# Since the velocity $c$ is constant in these examples, we can get the exact solution via D'Alembert. The general solution will be of the form
# $$u(x,t) = \phi(x+ct) + \psi(x-ct). $$
# Initial conditions tell use that
# $$u(x,0) = \phi(x) + \psi(x) = f(x), $$ and
# $$u_t(x,0) = c\phi'(x) - c\psi'(x) = g(x). $$
# With $G(x)$ the antiderivative of $g(x)$ with appropriate zero at zero, we get a 2x2 system
# $$\phi(x) + \psi(x) = f(x), \\ c(\phi(x) - \psi(x)) = G(x),$$
# which we solve as
# $$\phi(x) = \frac{1}{2}\left( f(x) + \frac{1}{c} G(x) \right), \\
#   \psi(x) = \frac{1}{2}\left( f(x) - \frac{1}{c} G(x) \right).$$
#
# Now $f(x)$ is given as the argument $u0$ in the code. $G(x)$ can be computed using scipy. The arguments $x+ct$ and $x-ct$ must be converted to integer indices. They have to wrap around. And with the zero boundary condition, we need to wrap around with a negative reflection.
#
# There is the messy question as to whether we require $u(0,t)$ to actually equal zero, or do we require it to be zero one index "to the left" of x=0. Let's not think too much about that just yet.

# %%
# Based on D'Alembert's solution, as described above
def w_solve3(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    c = np.sqrt(c2)  # the actual velocity parameter is needed
    f = u0  # use notation from above notes
    G = cumtrapz(u1,dx=dx,initial=0) # the antiderivative, using cumulative trapezoidal rule
    f2 = np.append(f,-f[::-1]) # odd symmetry
    G2 = np.append(G,G[::-1]) # even symmetry
    phi2 = (f2 + G2/c)/2
    psi2 = (f2 - G2/c)/2
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    # in the loop, we convert x+ct to index's into vectors phi2, psi2, modulo the vector length
    for j in range(t_len):
        ii1 = np.mod( np.round((x+c*t[j])/dx), 2*x_len)
        ii2 = np.mod( np.round((x-c*t[j])/dx), 2*x_len)
        u[:,j] = phi2[ii1.astype(int)] + psi2[ii2.astype(int)]
    return u,x,t

# %%
(u,x,t)=w_solve3(.5,dx,dt,t_len,1*triangle,0*triangle)

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert solution", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="347300fb-9fbe-46bf-944e-636d2fb73032"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("347300fb-9fbe-46bf-944e-636d2fb73032");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '347300fb-9fbe-46bf-944e-636d2fb73032' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ef477b6a-0d35-4b7a-974d-a9475737e947":{"roots":{"references":[{"attributes":{"plot":{"id":"ef08fd42-541b-4119-90ce-4af8ac911799","subtype":"Figure","type":"Plot"}},"id":"9ad533f5-31f2-413d-a65b-480cec250277","type":"HelpTool"},{"attributes":{},"id":"9bde7dc6-22c1-46dd-8d6d-163809468fbb","type":"BasicTicker"},{"attributes":{},"id":"8f1190cd-2896-4ab6-a478-44f853d0b53a","type":"BasicTicker"},{"attributes":{},"id":"437959e8-98f5-45a0-9459-4b85000452c5","type":"BasicTicker"},{"attributes":{"formatter":{"id":"27950741-3c83-4e44-9cda-f95b13dcbec1","type":"BasicTickFormatter"},"plot":{"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"},"ticker":{"id":"8f1190cd-2896-4ab6-a478-44f853d0b53a","type":"BasicTicker"}},"id":"43afce8b-3aac-4df3-92ae-278b389c0ad5","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#2222aa"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2499b643-2437-4031-aecb-8c746fa8b1d4","type":"Line"},{"attributes":{"formatter":{"id":"db52d801-e4b1-408a-8fca-c55e2b14f560","type":"BasicTickFormatter"},"plot":{"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"},"ticker":{"id":"3f961d97-e53b-4c23-afca-11e446237d41","type":"BasicTicker"}},"id":"1d06d448-90dd-41dc-bf52-1aafdf4629ee","type":"LinearAxis"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"c76b3c6a-992d-4a39-92a2-9f855ee97065","type":"PanTool"},{"attributes":{"callback":null},"id":"65c6594c-db8c-44a7-a890-13a8bcd559ec","type":"DataRange1d"},{"attributes":{"plot":{"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"}},"id":"edca2512-13f1-4497-bad6-c1ec67cc4284","type":"PreviewSaveTool"},{"attributes":{"plot":{"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"}},"id":"3ed89648-cf02-40f7-a89f-3f375c2d42c0","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"91fc0baf-6937-465d-bfff-c5c5c88daf5d","type":"PreviewSaveTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"663e6150-bfbf-4b52-978d-011d203e07b1","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"fd42b7e6-480b-49dc-8060-870d55a79b3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"5f374463-b13f-4f37-9fc3-669a63cdcfd3","type":"BasicTicker"}},"id":"1a7f947b-04a7-4e11-9b68-77ab2b3f171f","type":"Grid"},{"attributes":{"data_source":{"id":"fb577899-414e-4509-b540-f726f4c0331b","type":"ColumnDataSource"},"glyph":{"id":"b92c98c6-6be2-4129-9f83-5e3c2cf4974d","type":"Line"},"hover_glyph":null,"name":"foo","nonselection_glyph":{"id":"e6cde027-ac7d-4230-bba5-5279dfc2747f","type":"Line"},"selection_glyph":null},"id":"f34a3667-87b0-46cd-81f9-f23c65fe213a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011,0.012,0.013000000000000001,0.014,0.015,0.016,0.017,0.018000000000000002,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026000000000000002,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036000000000000004,0.037,0.038,0.039,0.04,0.041,0.042,0.043000000000000003,0.044,0.045,0.046,0.047,0.048,0.049,0.05,0.051000000000000004,0.052000000000000005,0.053,0.054,0.055,0.056,0.057,0.058,0.059000000000000004,0.06,0.061,0.062,0.063,0.064,0.065,0.066,0.067,0.068,0.069,0.07,0.07100000000000001,0.07200000000000001,0.073,0.074,0.075,0.076,0.077,0.078,0.079,0.08,0.081,0.082,0.083,0.084,0.085,0.08600000000000001,0.08700000000000001,0.088,0.089,0.09,0.091,0.092,0.093,0.094,0.095,0.096,0.097,0.098,0.099,0.1,0.101,0.10200000000000001,0.10300000000000001,0.10400000000000001,0.105,0.106,0.107,0.108,0.109,0.11,0.111,0.112,0.113,0.114,0.115,0.116,0.117,0.11800000000000001,0.11900000000000001,0.12,0.121,0.122,0.123,0.124,0.125,0.126,0.127,0.128,0.129,0.13,0.131,0.132, ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[22]</strong>&gt;</code></p>

# %%
interact(update,k=(0,t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# ### Derivative initial condition

# %%
(u,x,t)=w_solve3(.5,dx,dt,3*t_len,0*triangle,1*triangle)

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert solution, Der Cond", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="dbfb07a9-2326-4531-94c0-968df2315d3d"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dbfb07a9-2326-4531-94c0-968df2315d3d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dbfb07a9-2326-4531-94c0-968df2315d3d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"877b1774-bc75-4fbd-aed0-b35e131a228d":{"roots":{"references":[{"attributes":{},"id":"9bde7dc6-22c1-46dd-8d6d-163809468fbb","type":"BasicTicker"},{"attributes":{},"id":"8f1190cd-2896-4ab6-a478-44f853d0b53a","type":"BasicTicker"},{"attributes":{"callback":null},"id":"daab490c-f859-433f-aed0-514350956af8","type":"DataRange1d"},{"attributes":{},"id":"437959e8-98f5-45a0-9459-4b85000452c5","type":"BasicTicker"},{"attributes":{"plot":{"id":"63222629-c903-4ee7-aa6c-17681415ff62","subtype":"Figure","type":"Plot"}},"id":"77a62dff-17c1-498b-b6a5-d96ae1228eab","type":"PanTool"},{"attributes":{"formatter":{"id":"27950741-3c83-4e44-9cda-f95b13dcbec1","type":"BasicTickFormatter"},"plot":{"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"},"ticker":{"id":"8f1190cd-2896-4ab6-a478-44f853d0b53a","type":"BasicTicker"}},"id":"43afce8b-3aac-4df3-92ae-278b389c0ad5","type":"LinearAxis"},{"attributes":{"below":[{"id":"1d06d448-90dd-41dc-bf52-1aafdf4629ee","type":"LinearAxis"}],"left":[{"id":"43afce8b-3aac-4df3-92ae-278b389c0ad5","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"1d06d448-90dd-41dc-bf52-1aafdf4629ee","type":"LinearAxis"},{"id":"27a73334-0685-49ac-8e9e-e23a4f6a11e6","type":"Grid"},{"id":"43afce8b-3aac-4df3-92ae-278b389c0ad5","type":"LinearAxis"},{"id":"0f656ca7-a3d0-4032-ba3c-dda8aeafb068","type":"Grid"},{"id":"3094cf12-cdaf-4752-ba36-b409e11cb1d6","type":"BoxAnnotation"},{"id":"b7813175-a02d-47ab-a902-eb10c3dd80a1","type":"GlyphRenderer"}],"title":"Implicit solution method, Der cond","tool_events":{"id":"c3935f38-f46f-450f-976e-d61a7d070d78","type":"ToolEvents"},"tools":[{"id":"4166f200-ff4b-4fed-8ce4-20bd4240698b","type":"PanTool"},{"id":"3ed89648-cf02-40f7-a89f-3f375c2d42c0","type":"WheelZoomTool"},{"id":"b0b8edfa-4f56-4f09-8ca7-70614c9eb85c","type":"BoxZoomTool"},{"id":"edca2512-13f1-4497-bad6-c1ec67cc4284","type":"PreviewSaveTool"},{"id":"5801b8a1-a5be-42f0-a9bd-d34e8a3df65f","type":"ResizeTool"},{"id":"b39e56c0-334b-40b3-8481-82b7b9e9e0ec","type":"ResetTool"},{"id":"4cde8458-f824-4472-8790-35e18706c3bd","type":"HelpTool"}],"x_range":{"id":"e5e8f45e-3598-4197-93f9-41c4a121fc2e","type":"DataRange1d"},"y_range":{"id":"5d19e57a-5dfe-4ec0-b43a-fce9a47190f8","type":"DataRange1d"}},"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#2222aa"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2499b643-2437-4031-aecb-8c746fa8b1d4","type":"Line"},{"attributes":{},"id":"e5a81b3a-39bb-4a1e-afb1-432643183fd7","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"c76b3c6a-992d-4a39-92a2-9f855ee97065","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a5d86a5b-9bcb-4055-81e8-8d534610e6df","type":"Line"},{"attributes":{"formatter":{"id":"225d54ec-cc87-41ea-9374-b4151a05fe9e","type":"BasicTickFormatter"},"plot":{"id":"63222629-c903-4ee7-aa6c-17681415ff62","subtype":"Figure","type":"Plot"},"ticker":{"id":"0b59d314-c354-42c1-bb0e-8b2123c10267","type":"BasicTicker"}},"id":"7fda4bd5-8ac9-47c6-a34f-d1831ae46605","type":"LinearAxis"},{"attributes":{"plot":{"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"}},"id":"3ed89648-cf02-40f7-a89f-3f375c2d42c0","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"91fc0baf-6937-465d-bfff-c5c5c88daf5d","type":"PreviewSaveTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"663e6150-bfbf-4b52-978d-011d203e07b1","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"fd42b7e6-480b-49dc-8060-870d55a79b3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"5f374463-b13f-4f37-9fc3-669a63cdcfd3","type":"BasicTicker"}},"id":"1a7f947b-04a7-4e11-9b68-77ab2b3f171f", ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[25]</strong>&gt;</code></p>

# %%
interact(update,k=(0,3*t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# # Comparing solutions
#
# In principle, we want these different solution methods to be directly comparable.
#
# So let's try this out, by computing the difference of two solution.
#
# Here we compare the explicit f.d. method with d'Alambert's method.

# %%
(u_exp,x,t)=w_solve1(.5,dx,dt,t_len,1*triangle,0*triangle)
(u_dal,x,t)=w_solve3(.5,dx,dt,t_len,1*triangle,0*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert minus explicit", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")

def update(k=0):
    src.data['y']=u_dal[:,k]-u_exp[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="7bfb13c5-4d57-412b-aa58-2ddfa747090f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7bfb13c5-4d57-412b-aa58-2ddfa747090f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7bfb13c5-4d57-412b-aa58-2ddfa747090f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"82a5efc6-460f-490b-93ad-04633f3ff684":{"roots":{"references":[{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"72395f86-db3f-4847-912d-1abba7c0a823","type":"ResizeTool"},{"attributes":{},"id":"9bde7dc6-22c1-46dd-8d6d-163809468fbb","type":"BasicTicker"},{"attributes":{},"id":"8f1190cd-2896-4ab6-a478-44f853d0b53a","type":"BasicTicker"},{"attributes":{"callback":null},"id":"daab490c-f859-433f-aed0-514350956af8","type":"DataRange1d"},{"attributes":{},"id":"437959e8-98f5-45a0-9459-4b85000452c5","type":"BasicTicker"},{"attributes":{"plot":{"id":"fd42b7e6-480b-49dc-8060-870d55a79b3d","subtype":"Figure","type":"Plot"}},"id":"f7cf4cfb-8d0f-4c7f-8994-27767733436c","type":"HelpTool"},{"attributes":{"plot":{"id":"63222629-c903-4ee7-aa6c-17681415ff62","subtype":"Figure","type":"Plot"}},"id":"77a62dff-17c1-498b-b6a5-d96ae1228eab","type":"PanTool"},{"attributes":{"plot":{"id":"08da659f-2744-4b67-9c07-e374b04a3830","subtype":"Figure","type":"Plot"}},"id":"308d4413-b907-466c-8d36-a4d576c6489b","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"27950741-3c83-4e44-9cda-f95b13dcbec1","type":"BasicTickFormatter"},"plot":{"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"},"ticker":{"id":"8f1190cd-2896-4ab6-a478-44f853d0b53a","type":"BasicTicker"}},"id":"43afce8b-3aac-4df3-92ae-278b389c0ad5","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#2222aa"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2499b643-2437-4031-aecb-8c746fa8b1d4","type":"Line"},{"attributes":{},"id":"e5a81b3a-39bb-4a1e-afb1-432643183fd7","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"c76b3c6a-992d-4a39-92a2-9f855ee97065","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a5d86a5b-9bcb-4055-81e8-8d534610e6df","type":"Line"},{"attributes":{},"id":"d0f5afaf-bc4f-46ec-8666-1d10e4896726","type":"BasicTicker"},{"attributes":{"callback":null},"id":"7a1ab867-1e4b-44cc-90e6-bb270d9ac604","type":"DataRange1d"},{"attributes":{"plot":{"id":"77ab7b8f-ef1a-4a7b-a21f-1ded4c0e706e","subtype":"Figure","type":"Plot"}},"id":"3ed89648-cf02-40f7-a89f-3f375c2d42c0","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"a58bd9df-d088-4306-ad56-713a46174e2b","type":"BasicTickFormatter"},"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"},"ticker":{"id":"9bde7dc6-22c1-46dd-8d6d-163809468fbb","type":"BasicTicker"}},"id":"3ab5bf88-9f84-4170-9bd8-dab6c873c0bc","type":"LinearAxis"},{"attributes":{"callback":null},"id":"2160ec7a-ee89-4b4a-8836-8f1eeced8d0b","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8cdd7799-7700-40bd-b783-6d8660daefc0","type":"Line"},{"attributes":{"plot":{"id":"63222629-c903-4ee7-aa6c-17681415ff62","subtype":"Figure","type":"Plot"},"ticker":{"id":"0b59d314-c354-42c1-bb0e-8b2123c10267","type":"BasicTicker"}},"id":"49c03e71-fa8c-419a-91c3-583278c6e3be","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011,0.012,0.013000000000000001,0.014,0.015,0.016,0.017,0.018000000000000002,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026000000000000002,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036000000000000004,0.037,0.038,0.039,0.04,0.041,0.042,0.043000000000000003,0.044,0.045,0.046,0.047,0.048,0.049,0.05,0.051000000000000004,0.052000000000000005,0.053,0.054,0.055,0.056,0.057,0.058,0.059000000000000004,0.06,0.061,0.062,0.063,0.064,0.065,0.066,0.067,0.068,0.069,0.07,0.07100000000000001,0.07200000000000001,0.073,0.074,0.075,0.076,0.077,0.078,0.079,0.08,0.081,0.082,0.083,0.084,0.085,0.08600000000000001,0.08700000000000001,0.088,0.089,0.09,0.091,0. ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[28]</strong>&gt;</code></p>

# %%
interact(update,k=(0,t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# ## A moving wavefront
#
# Let's try an actual wave. We want something like
# $$u(x,t) = \exp(-(x -x_a-ct)^2/w^2), $$
# where $x_a$ is the center of the Gaussian at $t=0$, $w$ is the width of the Gaussian, $c$ is the velocity of the wave.
#
# This gives
# $$u_0(x) = \exp(-(x -x_a)^2/w^2) \\
#   u_1(x) = \frac{2c(x-x_a)}{w^2}\exp(-(x -x_a)^2/w^2) = \frac{2c(x-x_a)}{w^2}u_0(x).$$

# %%
c = .707  # velocity
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
u0 = np.exp(-(x-.5)*(x-.5)/.01)
u1 = 2*c*u0*(x-.5)/.01

# %%
(u,x,t)=w_solve3(c*c,dx,dt,t_len,u0,u1)  # notice we input the velocity squared!

# %%
y=u[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))
p = figure(title="Moving wave", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="4301ba1d-6317-4273-8ae4-37ad8156d30f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4301ba1d-6317-4273-8ae4-37ad8156d30f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4301ba1d-6317-4273-8ae4-37ad8156d30f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"87fbf563-d675-4d72-97a0-8205ac202ab3":{"roots":{"references":[{"attributes":{},"id":"a514e15a-3903-4a00-ba35-965becb474b1","type":"ToolEvents"},{"attributes":{"plot":{"id":"338208f9-9435-4c38-940c-a3986a084e19","subtype":"Figure","type":"Plot"}},"id":"c76b3c6a-992d-4a39-92a2-9f855ee97065","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"d30ef215-dfe1-4052-a03d-9e70a88f0d27","subtype":"Figure","type":"Plot"},"ticker":{"id":"16be3592-1d37-433f-bb33-11ce245cf31e","type":"BasicTicker"}},"id":"2532fc72-fab2-422a-ba35-d6084fdf8f68","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"663e6150-bfbf-4b52-978d-011d203e07b1","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"fd42b7e6-480b-49dc-8060-870d55a79b3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"5f374463-b13f-4f37-9fc3-669a63cdcfd3","type":"BasicTicker"}},"id":"1a7f947b-04a7-4e11-9b68-77ab2b3f171f","type":"Grid"},{"attributes":{"data_source":{"id":"fb577899-414e-4509-b540-f726f4c0331b","type":"ColumnDataSource"},"glyph":{"id":"b92c98c6-6be2-4129-9f83-5e3c2cf4974d","type":"Line"},"hover_glyph":null,"name":"foo","nonselection_glyph":{"id":"e6cde027-ac7d-4230-bba5-5279dfc2747f","type":"Line"},"selection_glyph":null},"id":"f34a3667-87b0-46cd-81f9-f23c65fe213a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"08da659f-2744-4b67-9c07-e374b04a3830","subtype":"Figure","type":"Plot"}},"id":"370a2fa8-9a99-4a5b-8cb4-97fdab1a1d71","type":"ResetTool"},{"attributes":{},"id":"225d54ec-cc87-41ea-9374-b4151a05fe9e","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"cf03c425-41c4-45a0-92f6-6e7b9d1c95f3","type":"BasicTickFormatter"},"plot":{"id":"8f2fd910-5049-4770-b11a-c1221ac6dda8","subtype":"Figure","type":"Plot"},"ticker":{"id":"d0f5afaf-bc4f-46ec-8666-1d10e4896726","type":"BasicTicker"}},"id":"8b0e334c-3133-4d2b-af22-2f00c668712c","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"98c6ad85-ff57-4f42-ab26-99d3294958c0","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"97b04569-2733-4c96-9b64-6fbcf943acb9","type":"ColumnDataSource"},"glyph":{"id":"904aea90-086f-434d-b657-7c49161f12ae","type":"Line"},"hover_glyph":null,"name":"foo","nonselection_glyph":{"id":"c1aae3ea-2f85-4906-a4fa-4695686b889e","type":"Line"},"selection_glyph":null},"id":"b7813175-a02d-47ab-a902-eb10c3dd80a1","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"24f7632f-4e78-49d6-8b70-71b380bf9312","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011,0.012,0.013000000000000001,0.014,0.015,0.016,0.017,0.018000000000000002,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026000000000000002,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036000000000000004,0.037,0.038,0.039,0.04,0.041,0.042,0.043000000000000003,0.044,0.045,0.046,0.047,0.048,0.049,0.05,0.051000000000000004,0.052000000000000005,0.053,0.054,0.055,0.056,0.057,0.058,0.059000000000000004,0.06,0.061,0.062,0.063,0.064,0.065,0.066,0.067,0.068,0.069,0.07,0.07100000000000001,0.07200000000000001,0.073,0.074,0.075,0.076,0.077,0.078,0.079,0.08,0.081,0.082,0.083,0.084,0.085,0.08600000000000001,0.08700000000000001,0.088,0.089,0.09,0.091,0.092,0.093,0.094,0.095,0.096,0.097,0.098,0.099,0.1,0.101,0.10200000000000001,0.10300000000000001,0.10400000000000001,0.105,0.106,0.107,0.108,0.109,0.11,0.111,0.112,0.113,0.114,0.115,0.116,0.117,0.11800000000000001,0.11900000000000001,0.12,0.121,0.122,0.123,0.124,0.125,0.126,0.127,0.128,0.1 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[32]</strong>&gt;</code></p>

# %%
interact(update,k=(0,t_len-1))
# Out:
# <function __main__.update>

# %% [markdown]
# ## Some dangerous code
#
# For the record, here is some code I wrote that did live animations and 2D displays.
#
# However, it seems to break our Jupyter Hub, perhaps because Bokeh can't handle these large amounts of data.

# %%
## Initial setup
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# %%
# Here we solve the wave equation, with initial position $u(x,0)$ set to the triangle waveform
(u,x,t)=w_solve1(.5,dx,dt,t_len,triangle,0*triangle)

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))
p = figure(title="Finite difference, explicit method", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")
show(p)

# %%
# WARNING. This creates a lot of data, may swamp the CPU. 
# This runs an animation, to view the wave as it propogates
for k in range(t_len):
    src.data['y'] = u[:,k]
    push_notebook()

# %%
# WARNING: This cell will make everything else run slow, and may crash Jupyter!!!
p = figure(x_range=(0, 1), y_range=(0, 1))
p.image(image=[u.transpose()], x=0, y=0, dw=1, dh=1, palette="Spectral11")
show(p)
