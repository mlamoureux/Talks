# %% [markdown]
# # WaveSolver - slider
# M. Lamoureux May 31, 2016. Pacific Insitute for the Mathematical Sciences
#
# This code does some numerical simulation of wave propagation in 1D, suitable for demoing in a class.
#
# This is a rewrite of some of my old Julia code, translated to run in Python. My belief is that Python is a more mature system and I will likely be more productive by sticking to Python instead of Julia. Let's see if this is true.
#
# The code is based on formulas from the textbook Linear Partial Differential Equations for Scientists and Engineers, by Myint-U and Debnath. It's a good book -- you should buy it. Some extracts are also available online.
#
# In this Jupyter notebook, animation has been added, using GUI sliders to advance the waveform in time.
#
#
# This was also written as a test of how far we can push Bokeh and the Jupyter Hub in making some calculations and graphics. There is some dangerous code at the bottom, that can bring down our Jupyter Hub, probably because it eats up too much memory. Interesting for debugging purposes, but you have been warned.

# %% [markdown]
# ## Introduction to the 1D wave equation.
#
# The basic idea is to represent the vibrations of a (horizonal) string under tension by a function $u(x,t)$ where $x$ is the horizontal displacement along the string, $t$ is the time parameter, and $y=u(x,t)$ indicates the (vertical) displacement of the string at point $x$ along the string, at time $t$
#
# A typical wave would look something like
# $$u(x,t) = \sin(x-ct)$$
# which represents a sinusoidal wave moving to the right at velocity $c$.
#
# From Newon's law of motion (mass times acceleration equals force), we can derive the wave equation for the string in the form
# $$ \rho \cdot u_{tt} = k \cdot u_{xx}$$
# where $\rho$ is a mass density, $u_{tt}$ is an acceleration (the second derivative w.r.t. time), $k$ is the modulus of elasticity and $u_{xx}$ is a measure of curvature (the second derivative w.r.t. $x$), causing the bending force.
#
# Including boundary and initial conditions, while setting the parameter $c^2 = k/\rho$, we obtain the usual 1D wave equation on an interval as this:
#
#
# $$u_{tt} = c^2 u_{xx} \mbox{ on interval } [x_0,x_1]$$
# subject to boundary conditions
# $$u(x_0,t) = u(x_1, t) = 0 \mbox{ for all $t$. }$$
# and initial conditions
# $$u(x,0) = u_0(x), \quad u_t(x,t) = u_1(x) \mbox{ on interval } [x_0,x_1].$$
#
#
# Let's write some PDE solvers for this 1D wave equation.
#
# Start with some simple solvers, then get more complex.
#
# The function to solve the PDE needs to know $c^2, u_0, u_1$, the sampling intervals $dx$ and $dt$, and the number of time steps to execute. Everything else can be inferred from those inputs. The output should be a 2D array, indexed in x and t steps.
#
# Maybe we could actually output the solution $u(x,t)$ as well as the vector of indices for $x$ and $t$.

# %% [markdown]
# ## Software tools
# We import some tools for numerical work (NumPy) and plotting (Boken), using Boken because it is faster than matplotlib).

# %%
from bokeh.models import ColumnDataSource
from bokeh.plotting import *
from bokeh.io import push_notebook
import numpy as np

# %% [markdown]
# We also include some code from SciPy for numerical calculations

# %%
from scipy.linalg import solve_toeplitz  # a matrix equation solver
from scipy.integrate import cumtrapz # a numerical integrator, using trapezoid rule

# %% [markdown]
# And we include some code to create the graphical user interface -- namely, sliders. You can read about them here:
# http://bokeh.pydata.org/en/0.10.0/_images/notebook_interactors.png

# %%
from ipywidgets import interact

# %% [markdown]
# ## Explicit method of solution in finite differences
#
# The finite difference method is probably the most common numerical method for solving PDEs. The derivatives are approximated by Newton difference ratios, and you step through in time to progress the solution from $t=0$ to some ending time.
#
# The following defines a function that solves the wave equation, using an explicit finite difference method. We follow the notes in the referenced book by Myint-U and Debnath.
#
# The differencing in spatial variable $x$ is done by a convolution, as this will be fast.
#
# We print out the value of the CFL constant as a sanity check. The method is stable and convergent provided the CFL value is less than one. (This means $dt$ needs to be small enough.) See the book for details.
#
# The input parameters are velocity squared $c2$, spatial step size $dx$, temporal step size $dt$, number of time steps $t$_$len$, initial position $u0$ and initial velocity $u1$. $u0$ and $u1$ are arrays of some length $N$, which the code will use to deduce everything it needs to know.
#
# I tend to think of these as dimensionless variables, but you can use real physical values if you like, so long as you are consistent. For instance $dx$ in meters, $dt$ in seconds, and $c2$ in (meters/second) squared.

# %%
# Based on Section 14.4 in Myint-U and Debnath's book
def w_solve1(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    e2 = c2*dt*dt/(dx*dx)  # Courant parameter squared (test for convergence!)
    print("CFL value is ",np.sqrt(e2))
    kern = np.array([e2, 2*(1-e2), e2]) # the convolution kernel we need for laplacian solver
    u[:,0] = u0            # t=0 initial condition
    u[:,1] = np.convolve(u0,kern/2)[1:x_len+1] + dt*u1 # t=0 derivative condition, eqn 14.4.6
    for j in range(2,t_len):
        u[:,j] = np.convolve(u[:,j-1],kern)[1:x_len+1] - u[:,j-2] # eqn 14.4.3
    # let's produce the x and t vectors, in case we need them
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    return u,x,t

# %% [markdown]
# Let's try a real wave equation solution.
#
# We start with a simple triangle waveform.

# %%
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# %% [markdown]
# Now we call up our wave equation solver, using the parameters above

# %%
# Here we solve the wave equation, with initial position $u(x,0)$ set to the triangle waveform
(u,x,t)=w_solve1(.5,dx,dt,t_len,triangle,0*triangle)
# Out:
# CFL value is  0.707106781187

# %% [markdown]
# We initialize the plotting tools in Bokeh and plot the initial waveform.

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5de2e498-35ed-4c9c-b669-8f10b1ba5a79">Loading BokehJS ...</span>
#     </div>

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="F.D. Explicit method solution", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()

show(p)
# Out:
#     <div class="plotdiv" id="cd595179-264e-4452-89fd-8836c0984bec"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cd595179-264e-4452-89fd-8836c0984bec");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cd595179-264e-4452-89fd-8836c0984bec' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"124e50da-5f5f-4b8f-84ad-6277aa092917":{"roots":{"references":[{"attributes":{"line_color":{"value":"#2222aa"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3df2a510-54ae-4cf0-986b-ab3a529e6e0a","type":"Line"},{"attributes":{"formatter":{"id":"c1cdd598-7eee-4b52-85a8-c7d8c15c976a","type":"BasicTickFormatter"},"plot":{"id":"172113ac-8daa-437e-9b41-41ec2ff43c02","subtype":"Figure","type":"Plot"},"ticker":{"id":"8b3deff5-09f4-4e62-9eba-461956d2ceee","type":"BasicTicker"}},"id":"e61de4b8-0668-47d8-80f8-9e74442ee724","type":"LinearAxis"},{"attributes":{"callback":null},"id":"b3bbb459-937d-42c5-a607-33c85ab3dc15","type":"DataRange1d"},{"attributes":{"plot":{"id":"8248eaa3-771d-4c9b-96c6-feed34a378bd","subtype":"Figure","type":"Plot"},"ticker":{"id":"1332d7c7-2861-4b2d-8cb9-881937dc2696","type":"BasicTicker"}},"id":"e9013563-7d1c-4a2e-982d-a6cb37b8e2d3","type":"Grid"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"50fe7b4d-fff8-4452-9679-2e07c19ec102","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011,0.012,0.013000000000000001,0.014,0.015,0.016,0.017,0.018000000000000002,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026000000000000002,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036000000000000004,0.037,0.038,0.039,0.04,0.041,0.042,0.043000000000000003,0.044,0.045,0.046,0.047,0.048,0.049,0.05,0.051000000000000004,0.052000000000000005,0.053,0.054,0.055,0.056,0.057,0.058,0.059000000000000004,0.06,0.061,0.062,0.063,0.064,0.065,0.066,0.067,0.068,0.069,0.07,0.07100000000000001,0.07200000000000001,0.073,0.074,0.075,0.076,0.077,0.078,0.079,0.08,0.081,0.082,0.083,0.084,0.085,0.08600000000000001,0.08700000000000001,0.088,0.089,0.09,0.091,0.092,0.093,0.094,0.095,0.096,0.097,0.098,0.099,0.1,0.101,0.10200000000000001,0.10300000000000001,0.10400000000000001,0.105,0.106,0.107,0.108,0.109,0.11,0.111,0.112,0.113,0.114,0.115,0.116,0.117,0.11800000000000001,0.11900000000000001,0.12,0.121,0.122,0.123,0.124,0.125,0.126,0.127,0.128,0.129,0.13,0.131,0.132,0.133,0.134,0.135,0.136,0.137,0.138,0.139,0.14,0.14100000000000001,0.14200000000000002,0.14300000000000002,0.14400000000000002,0.145,0.146,0.147,0.148,0.149,0.15,0.151,0.152,0.153,0.154,0.155,0.156,0.157,0.158,0.159,0.16,0.161,0.162,0.163,0.164,0.165,0.166,0.167,0.168,0.169,0.17,0.171,0.17200000000000001,0.17300000000000001,0.17400000000000002,0.17500000000000002,0.176,0.177,0.178,0.179,0.18,0.181,0.182,0.183,0.184,0.185,0.186,0.187,0.188,0.189,0.19,0.191,0.192,0.193,0.194,0.195,0.196,0.197,0.198,0.199,0.2,0.201,0.202,0.203,0.20400000000000001,0.20500000000000002,0.20600000000000002,0.20700000000000002,0.20800000000000002,0.209,0.21,0.211,0.212,0.213,0.214,0.215,0.216,0.217,0.218,0.219,0.22,0.221,0.222,0.223,0.224,0.225,0.226,0.227,0.228,0.229,0.23,0.231,0.232,0.233,0.234,0.23500000000000001,0.23600000000000002,0.23700000000000002,0.23800000000000002,0.23900000000000002,0.24,0.241,0.242,0.243,0.244,0.245,0.246,0.247,0.248,0.249,0.25,0.251,0.252,0.253,0.254,0.255,0.256,0.257,0.258,0.259,0.26,0.261,0.262,0.263,0.264,0.265,0.266,0.267,0.268,0.269,0.27,0.271,0.272,0.273,0.274,0.275,0.276,0.277,0.278,0.279,0.28,0.281,0.28200000000000003,0.28300000000000003,0.28400000000000003,0.28500000000000003,0.28600000000000003,0.28700000000000003,0.28800000000000003,0.289,0.29,0.291,0.292,0.293,0.294,0.295,0.296,0.297,0.298,0.299,0.3,0.301,0.302,0.303,0.304,0.305,0.306,0.307,0.308,0.309,0.31,0.311,0.312,0.313,0.314,0.315,0.316,0.317,0.318,0.319,0.32,0.321,0.322,0.323,0.324,0.325,0.326,0.327,0.328,0.329,0.33,0.331,0.332,0.333,0.334,0.335,0.336,0.337,0.338,0.339,0.34,0.341,0.342,0.343,0.34400000000000003,0.34500000000000003,0.34600000000000003,0.34700000000000003,0.34800000000000003,0.34900000000000003,0.35000000000000003,0.35100000000000003,0.352,0.353,0.354,0.355,0.356,0.357,0.358,0.359,0.36,0.361 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %% [markdown]
# And the next cell sets up a slider which controls the above graphs (it moves time along)

# %%
# This runs an animation, controlled by a slider which advances time
interact(update,k=(0,t_len-1))

# %% [markdown]
# ### Derivative initial condition test

# %%
# We try again, but this time with the $u_t$ initial condition equal to the triangle impulse
(u,x,t)=w_solve1(.5,dx,dt,3*t_len,0*triangle,1*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="F.D. Explicit method solution, Der Cond", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="c5037356-13c6-4d94-b468-23f49cb9473f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c5037356-13c6-4d94-b468-23f49cb9473f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c5037356-13c6-4d94-b468-23f49cb9473f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7b0080df-ee7a-40a5-89a4-29f945440331":{"roots":{"references":[{"attributes":{},"id":"485f0e5e-668f-4ef6-865f-285602775e83","type":"ToolEvents"},{"attributes":{"overlay":{"id":"fcdc1256-ffee-4ad2-aaf0-a41e63a2073f","type":"BoxAnnotation"},"plot":{"id":"8304b83b-26dc-48b2-851f-a90a7bcf5f03","subtype":"Figure","type":"Plot"}},"id":"dd39df66-b478-46de-9cd5-c9e01fccb68b","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"d10b9831-165b-4bbb-89be-468eda94b454","subtype":"Figure","type":"Plot"}},"id":"1118363f-4a36-4aa5-9982-2638745d2f7f","type":"WheelZoomTool"},{"attributes":{},"id":"84bd41d6-a67f-4b8e-b1aa-45a0fb5320af","type":"BasicTicker"},{"attributes":{},"id":"4b3ef7da-bd83-4974-9a6c-a48106b16839","type":"BasicTicker"},{"attributes":{"below":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"}],"left":[{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"},{"id":"eb77c811-1f61-476b-9105-8401de78f623","type":"Grid"},{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"},{"id":"b133c9df-ff4f-4a0e-98d9-50ee2d6896b6","type":"Grid"},{"id":"c923bdde-af78-48d2-91e2-a81dc8736ef7","type":"BoxAnnotation"},{"id":"66e93b08-0b45-45bf-adac-003a5a1d6a12","type":"GlyphRenderer"}],"title":"F.D. Explicit method solution, Der Cond","tool_events":{"id":"485f0e5e-668f-4ef6-865f-285602775e83","type":"ToolEvents"},"tools":[{"id":"c2b65358-025c-4bf6-aabc-00cee0abdaeb","type":"PanTool"},{"id":"91eb13c8-c357-4074-bda2-a1cfdf4e8c34","type":"WheelZoomTool"},{"id":"da5b6def-13d3-46f8-b904-0334e5f71b49","type":"BoxZoomTool"},{"id":"6eaedf4d-b2fa-415c-93c7-23afd8c89b87","type":"PreviewSaveTool"},{"id":"a28aa9da-b4a1-43ec-bc3b-fd8a0c6da294","type":"ResizeTool"},{"id":"98a32f87-afd0-4d74-a861-2e55d4b274d6","type":"ResetTool"},{"id":"cf989ecf-c843-4c0f-913e-91e10b532f5c","type":"HelpTool"}],"x_range":{"id":"9b387751-84ba-45c8-ae1e-3e909d3f6992","type":"DataRange1d"},"y_range":{"id":"90cf8f09-5564-4c89-abc9-e0fc72d92e58","type":"DataRange1d"}},"id":"89bbc7d4-b1c9-4113-b2f9-7acfc6c5e5d5","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"b62aba2a-753a-4203-87f2-48efdce66b67","type":"Line"},{"attributes":{"formatter":{"id":"fd2d5596-1693-4db3-b437-ec6757589ea4","type":"BasicTickFormatter"},"plot":{"id":"89bbc7d4-b1c9-4113-b2f9-7acfc6c5e5d5","subtype":"Figure","type":"Plot"},"ticker":{"id":"fa784e22-dcdb-4075-8988-6b7fcd61d7bb","type":"BasicTicker"}},"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011,0.012,0.013000000000000001,0.014,0.015,0.016,0.017,0.018000000000000002,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026000000000000002,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036000000000000004,0.037,0.038,0.039,0.04,0.041,0.042,0.043000000000000003,0.044,0.045,0.046,0.047,0.048,0.049,0.05,0.051000000000000004,0.052000000000000005,0.053,0.054,0.055,0.056,0.057,0.058,0.059000000000000004,0.06,0.061,0.062,0.063,0.064,0.065,0.066,0.067,0.068,0.069,0.07,0.07100000000000001,0.07200000000000001,0.073,0.074,0.075,0.076,0.077,0.078,0.079,0.08,0.081,0.082,0.083,0.084,0.085,0.08600000000000001,0.08700000000000001,0.088,0.089,0.09,0.091,0.092,0.093,0.094,0.095,0.096,0.097,0.098,0.099,0.1,0.101,0.10200000000000001,0.10300000000000001,0.10400000000000001,0.105,0.106,0.107,0.108,0.109,0.11,0.111,0.112,0.113,0.114,0.115,0.116,0.117,0.11800000000000001,0.11900000000000001,0.12,0.121,0.122,0.123,0.124,0.125,0.126,0.127,0.128,0.129,0.13,0.131,0.132,0.133,0.134,0.135,0.136,0.137,0.138,0.139,0.14,0.14100000000000001,0.14200000000000002,0.14300000000000002,0.14400000000000002,0.145,0.146,0.147,0.148,0.149,0.15,0.151,0.152,0.153,0.154,0.155,0.156,0 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
interact(update,k=(0,3*t_len-1))

# %% [markdown]
# ## Implicit method
#
# Here we try an implicit method for solving the wave equation. Again from Myint-U and Debnath's book, in Section 14.5, part (B) on Hyperbolic equations.
#
# We need to use scipy libraries as we have to solve a system of linear equation. In fact the system is tridiagonal and Toepliz, so this should be fast. I see how to use Toepliz in scipy, but I don't know how to tell it that the system is only tridiagonal. It should be possible to speed this up.

# %%
# Based on Section 14.5 (B) in Myint-U and Debnath's book
def w_solve2(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    e2 = c2*dt*dt/(dx*dx)  # Courant parameter squared (test for convergence!)
    print("CFL value is ",np.sqrt(e2))
    kern = np.array([e2, 2*(1-e2), e2]) # the convolution kernel we need for laplacian solver
    u[:,0] = u0            # t=0 initial condition
    u[:,1] = np.convolve(u0,kern/2)[1:x_len+1] + dt*u1 # t=0 derivative condition, eqn 14.4.6
    # Note the above is a cheat, we are using the explicit method to find u[:,1], Should do this implicitly
    kern2 = np.array([e2, -2*(1+e2), e2]) # the convolution kernel we need for implicit solver. It is different.
    toepk = np.zeros(x_len)  # this will hold the entries for the tridiagonal Toeplitz matrix
    toepk[0] = 2*(1+e2);
    toepk[1] = -e2
    for j in range(2,t_len):
        rhs = np.convolve(u[:,j-2],kern2)[1:x_len+1] + 4*u[:,j-1] # eqn 14.5.17
        u[:,j] = solve_toeplitz(toepk, rhs) # here is a linear system solver (hence an implicit method)
    # let's produce the x and t vectors, in case we need them
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    return u,x,t

# %%
(u,x,t)=w_solve2(.5,dx,dt,t_len,1*triangle,0*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="Implicit solution method", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="2992b210-bcda-42a6-847f-9807ef479164"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2992b210-bcda-42a6-847f-9807ef479164");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2992b210-bcda-42a6-847f-9807ef479164' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2c482c7c-4bc6-47ea-b34e-641665df6245":{"roots":{"references":[{"attributes":{},"id":"485f0e5e-668f-4ef6-865f-285602775e83","type":"ToolEvents"},{"attributes":{"overlay":{"id":"c923bdde-af78-48d2-91e2-a81dc8736ef7","type":"BoxAnnotation"},"plot":{"id":"89bbc7d4-b1c9-4113-b2f9-7acfc6c5e5d5","subtype":"Figure","type":"Plot"}},"id":"da5b6def-13d3-46f8-b904-0334e5f71b49","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"26ca92a5-113e-4366-af53-70b2c0e1d0f0","type":"BasicTickFormatter"},"plot":{"id":"22262139-6a4b-42b1-bf5c-1780744bb385","subtype":"Figure","type":"Plot"},"ticker":{"id":"6f92f3ed-3af0-495c-8ed4-6a274badd69e","type":"BasicTicker"}},"id":"f363c18c-1d91-4561-a3cd-79277dba966b","type":"LinearAxis"},{"attributes":{"below":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"}],"left":[{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"},{"id":"eb77c811-1f61-476b-9105-8401de78f623","type":"Grid"},{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"},{"id":"b133c9df-ff4f-4a0e-98d9-50ee2d6896b6","type":"Grid"},{"id":"c923bdde-af78-48d2-91e2-a81dc8736ef7","type":"BoxAnnotation"},{"id":"66e93b08-0b45-45bf-adac-003a5a1d6a12","type":"GlyphRenderer"}],"title":"F.D. Explicit method solution, Der Cond","tool_events":{"id":"485f0e5e-668f-4ef6-865f-285602775e83","type":"ToolEvents"},"tools":[{"id":"c2b65358-025c-4bf6-aabc-00cee0abdaeb","type":"PanTool"},{"id":"91eb13c8-c357-4074-bda2-a1cfdf4e8c34","type":"WheelZoomTool"},{"id":"da5b6def-13d3-46f8-b904-0334e5f71b49","type":"BoxZoomTool"},{"id":"6eaedf4d-b2fa-415c-93c7-23afd8c89b87","type":"PreviewSaveTool"},{"id":"a28aa9da-b4a1-43ec-bc3b-fd8a0c6da294","type":"ResizeTool"},{"id":"98a32f87-afd0-4d74-a861-2e55d4b274d6","type":"ResetTool"},{"id":"cf989ecf-c843-4c0f-913e-91e10b532f5c","type":"HelpTool"}],"x_range":{"id":"9b387751-84ba-45c8-ae1e-3e909d3f6992","type":"DataRange1d"},"y_range":{"id":"90cf8f09-5564-4c89-abc9-e0fc72d92e58","type":"DataRange1d"}},"id":"89bbc7d4-b1c9-4113-b2f9-7acfc6c5e5d5","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"fcdc1256-ffee-4ad2-aaf0-a41e63a2073f","type":"BoxAnnotation"},"plot":{"id":"8304b83b-26dc-48b2-851f-a90a7bcf5f03","subtype":"Figure","type":"Plot"}},"id":"dd39df66-b478-46de-9cd5-c9e01fccb68b","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"d10b9831-165b-4bbb-89be-468eda94b454","subtype":"Figure","type":"Plot"}},"id":"1469affb-595b-4f51-a353-542cb15389f8","type":"ResizeTool"},{"attributes":{"overlay":{"id":"643b88df-bafc-4ab1-8ebe-e50979ab7042","type":"BoxAnnotation"},"plot":{"id":"22262139-6a4b-42b1-bf5c-1780744bb385","subtype":"Figure","type":"Plot"}},"id":"d13f2e5f-e554-44ae-a8fb-0c76bb0e956a","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"50fe7b4d-fff8-4452-9679-2e07c19ec102","type":"Line"},{"attributes":{"plot":{"id":"d10b9831-165b-4bbb-89be-468eda94b454","subtype":"Figure","type":"Plot"}},"id":"7b090fb6-3f13-4a0a-8e79-c846ca212991","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011,0.012,0.013000000000000001,0.014,0.015,0.016,0.017,0.018000000000000002,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026000000000000002,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036000000000000004,0.037,0.038,0.039,0.04,0.041,0.042,0.043000000000000003,0.044,0.045,0.046,0.047,0.048,0.049,0.05,0.051000000000000004,0.052000000000000005,0.053,0.054,0.055,0.056,0.057,0.058,0.059000000000000004,0.06,0.061,0.062,0.063,0.064,0.065,0.066,0.067,0.068,0.069,0.07,0.07100000000000001,0.07200000000000001,0.073,0.074,0.075,0.076,0.077,0.078,0.079,0.08,0.081,0.082,0.083,0.084,0.085,0.08600000000000001,0.08700000000000001,0.088,0.089,0.09,0.091,0.092,0.093,0.094,0 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
interact(update,k=(0,3*t_len-1))

# %% [markdown]
# ### Derivative initial condition

# %%
(u,x,t)=w_solve2(.5,dx,dt,3*t_len,0*triangle,1*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="Implicit solution method, Der cond", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="aed8bc3e-52d0-4d46-9763-4ab8d229e6b7"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aed8bc3e-52d0-4d46-9763-4ab8d229e6b7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aed8bc3e-52d0-4d46-9763-4ab8d229e6b7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c637e866-64a7-4c96-902c-c0c01b2bec36":{"roots":{"references":[{"attributes":{"below":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"}],"left":[{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"},{"id":"eb77c811-1f61-476b-9105-8401de78f623","type":"Grid"},{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"},{"id":"b133c9df-ff4f-4a0e-98d9-50ee2d6896b6","type":"Grid"},{"id":"c923bdde-af78-48d2-91e2-a81dc8736ef7","type":"BoxAnnotation"},{"id":"66e93b08-0b45-45bf-adac-003a5a1d6a12","type":"GlyphRenderer"}],"title":"F.D. Explicit method solution, Der Cond","tool_events":{"id":"485f0e5e-668f-4ef6-865f-285602775e83","type":"ToolEvents"},"tools":[{"id":"c2b65358-025c-4bf6-aabc-00cee0abdaeb","type":"PanTool"},{"id":"91eb13c8-c357-4074-bda2-a1cfdf4e8c34","type":"WheelZoomTool"},{"id":"da5b6def-13d3-46f8-b904-0334e5f71b49","type":"BoxZoomTool"},{"id":"6eaedf4d-b2fa-415c-93c7-23afd8c89b87","type":"PreviewSaveTool"},{"id":"a28aa9da-b4a1-43ec-bc3b-fd8a0c6da294","type":"ResizeTool"},{"id":"98a32f87-afd0-4d74-a861-2e55d4b274d6","type":"ResetTool"},{"id":"cf989ecf-c843-4c0f-913e-91e10b532f5c","type":"HelpTool"}],"x_range":{"id":"9b387751-84ba-45c8-ae1e-3e909d3f6992","type":"DataRange1d"},"y_range":{"id":"90cf8f09-5564-4c89-abc9-e0fc72d92e58","type":"DataRange1d"}},"id":"89bbc7d4-b1c9-4113-b2f9-7acfc6c5e5d5","subtype":"Figure","type":"Plot"},{"attributes":{"below":[{"id":"62a9cd46-4e62-4994-9e85-6b1833e1ba60","type":"LinearAxis"}],"left":[{"id":"fae36daf-1052-434a-be5c-38330d9ebcc4","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"62a9cd46-4e62-4994-9e85-6b1833e1ba60","type":"LinearAxis"},{"id":"6f6251b6-9a57-4686-b0dd-10bd4bbe6a13","type":"Grid"},{"id":"fae36daf-1052-434a-be5c-38330d9ebcc4","type":"LinearAxis"},{"id":"adc72504-a97b-493f-8593-d0c578b97c70","type":"Grid"},{"id":"fe4a382f-9e6e-42d2-a5fa-ea457f3f54af","type":"BoxAnnotation"},{"id":"0d671bfc-8823-4125-afb4-4d55c5830c7f","type":"GlyphRenderer"}],"title":"Implicit solution method, Der cond","tool_events":{"id":"7e7cc00d-c9a1-468a-acd7-edcc91e8df7b","type":"ToolEvents"},"tools":[{"id":"55a167b1-e8ab-4d8b-b6c3-9465d2ab073d","type":"PanTool"},{"id":"bd3b9e87-d835-42ee-a1d5-f73ee098453e","type":"WheelZoomTool"},{"id":"e629ec89-89b4-4bcc-9e4f-1ae106f55dc5","type":"BoxZoomTool"},{"id":"7e376623-be1e-4c48-aa77-d2fe56c72038","type":"PreviewSaveTool"},{"id":"e7ddcef9-d2ef-4cdc-9c74-f71a56dbf19a","type":"ResizeTool"},{"id":"b337eaba-ceb8-48e3-b9c3-7cb82a391c38","type":"ResetTool"},{"id":"97a8a74a-fc03-4610-a8e1-238ad3a79474","type":"HelpTool"}],"x_range":{"id":"1f73a499-e429-48c0-a390-6df422b2a381","type":"DataRange1d"},"y_range":{"id":"47215fb2-8b8f-4c4b-85dd-ddbc1e3f5e1a","type":"DataRange1d"}},"id":"36e86813-d472-4edf-825d-27c75d36780c","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"50fe7b4d-fff8-4452-9679-2e07c19ec102","type":"Line"},{"attributes":{"plot":{"id":"d10b9831-165b-4bbb-89be-468eda94b454","subtype":"Figure","type":"Plot"}},"id":"7b090fb6-3f13-4a0a-8e79-c846ca212991","type":"ResetTool"},{"attributes":{"callback":null},"id":"dcdcc9fc-339b-4602-9f2b-1149062e6c6f","type":"DataRange1d"},{"attributes":{},"id":"866442e2-dce3-49bd-bc6b-8a6cd1777e63","type":"BasicTicker"},{"attributes":{"data_source":{"id":"33188091-c766-41c8-b5de-7cf0cda263bd","type":"ColumnDataSource"},"glyph":{"id":"b62aba2a-753a-4203-87f2-48efdce66b67","type":"Line"},"hover_glyph":null,"name":"foo","nonselection_glyph":{"id":"9dc84147-0429-4daf-9b49-eb3fc1550ac5","type":"Line"},"selection_glyph":null},"id":"66e93b08-0b45-45bf-adac-003a5a1d6a12","type":"GlyphRenderer"},{"attributes":{},"id":"5e4169f2-48f8-42cc-8a72-f1466abcb1b1","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0. ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
interact(update,k=(0,3*t_len-1))

# %% [markdown]
# ## D'Alembert's solution
#
# Since the velocity $c$ is constant in these examples, we can get the exact solution via D'Alembert. The general solution will be of the form
# $$u(x,t) = \phi(x+ct) + \psi(x-ct). $$
# Initial conditions tell use that
# $$u(x,0) = \phi(x) + \psi(x) = f(x), $$ and
# $$u_t(x,0) = c\phi'(x) - c\psi'(x) = g(x). $$
# With $G(x)$ the antiderivative of $g(x)$ with appropriate zero at zero, we get a 2x2 system
# $$\phi(x) + \psi(x) = f(x), \\ c(\phi(x) - \psi(x)) = G(x),$$
# which we solve as
# $$\phi(x) = \frac{1}{2}\left( f(x) + \frac{1}{c} G(x) \right), \\
#   \psi(x) = \frac{1}{2}\left( f(x) - \frac{1}{c} G(x) \right).$$
#
# Now $f(x)$ is given as the argument $u0$ in the code. $G(x)$ can be computed using scipy. The arguments $x+ct$ and $x-ct$ must be converted to integer indices. They have to wrap around. And with the zero boundary condition, we need to wrap around with a negative reflection.
#
# There is the messy question as to whether we require $u(0,t)$ to actually equal zero, or do we require it to be zero one index "to the left" of x=0. Let's not think too much about that just yet.

# %%
# Based on D'Alembert's solution, as described above
def w_solve3(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    c = np.sqrt(c2)  # the actual velocity parameter is needed
    f = u0  # use notation from above notes
    G = cumtrapz(u1,dx=dx,initial=0) # the antiderivative, using cumulative trapezoidal rule
    f2 = np.append(f,-f[::-1]) # odd symmetry
    G2 = np.append(G,G[::-1]) # even symmetry
    phi2 = (f2 + G2/c)/2
    psi2 = (f2 - G2/c)/2
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    # in the loop, we convert x+ct to index's into vectors phi2, psi2, modulo the vector length
    for j in range(t_len):
        ii1 = np.mod( np.round((x+c*t[j])/dx), 2*x_len)
        ii2 = np.mod( np.round((x-c*t[j])/dx), 2*x_len)
        u[:,j] = phi2[ii1.astype(int)] + psi2[ii2.astype(int)]
    return u,x,t

# %%
(u,x,t)=w_solve3(.5,dx,dt,t_len,1*triangle,0*triangle)

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert solution", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="cd87b675-57d7-4a8e-88d1-71231a84a5f0"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cd87b675-57d7-4a8e-88d1-71231a84a5f0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cd87b675-57d7-4a8e-88d1-71231a84a5f0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"bf33a047-1c5c-487e-b5d2-767b49681e41":{"roots":{"references":[{"attributes":{},"id":"55f51a52-c509-497f-ab78-b1e9f9300f8a","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"}],"left":[{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"},{"id":"eb77c811-1f61-476b-9105-8401de78f623","type":"Grid"},{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"},{"id":"b133c9df-ff4f-4a0e-98d9-50ee2d6896b6","type":"Grid"},{"id":"c923bdde-af78-48d2-91e2-a81dc8736ef7","type":"BoxAnnotation"},{"id":"66e93b08-0b45-45bf-adac-003a5a1d6a12","type":"GlyphRenderer"}],"title":"F.D. Explicit method solution, Der Cond","tool_events":{"id":"485f0e5e-668f-4ef6-865f-285602775e83","type":"ToolEvents"},"tools":[{"id":"c2b65358-025c-4bf6-aabc-00cee0abdaeb","type":"PanTool"},{"id":"91eb13c8-c357-4074-bda2-a1cfdf4e8c34","type":"WheelZoomTool"},{"id":"da5b6def-13d3-46f8-b904-0334e5f71b49","type":"BoxZoomTool"},{"id":"6eaedf4d-b2fa-415c-93c7-23afd8c89b87","type":"PreviewSaveTool"},{"id":"a28aa9da-b4a1-43ec-bc3b-fd8a0c6da294","type":"ResizeTool"},{"id":"98a32f87-afd0-4d74-a861-2e55d4b274d6","type":"ResetTool"},{"id":"cf989ecf-c843-4c0f-913e-91e10b532f5c","type":"HelpTool"}],"x_range":{"id":"9b387751-84ba-45c8-ae1e-3e909d3f6992","type":"DataRange1d"},"y_range":{"id":"90cf8f09-5564-4c89-abc9-e0fc72d92e58","type":"DataRange1d"}},"id":"89bbc7d4-b1c9-4113-b2f9-7acfc6c5e5d5","subtype":"Figure","type":"Plot"},{"attributes":{"below":[{"id":"62a9cd46-4e62-4994-9e85-6b1833e1ba60","type":"LinearAxis"}],"left":[{"id":"fae36daf-1052-434a-be5c-38330d9ebcc4","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"62a9cd46-4e62-4994-9e85-6b1833e1ba60","type":"LinearAxis"},{"id":"6f6251b6-9a57-4686-b0dd-10bd4bbe6a13","type":"Grid"},{"id":"fae36daf-1052-434a-be5c-38330d9ebcc4","type":"LinearAxis"},{"id":"adc72504-a97b-493f-8593-d0c578b97c70","type":"Grid"},{"id":"fe4a382f-9e6e-42d2-a5fa-ea457f3f54af","type":"BoxAnnotation"},{"id":"0d671bfc-8823-4125-afb4-4d55c5830c7f","type":"GlyphRenderer"}],"title":"Implicit solution method, Der cond","tool_events":{"id":"7e7cc00d-c9a1-468a-acd7-edcc91e8df7b","type":"ToolEvents"},"tools":[{"id":"55a167b1-e8ab-4d8b-b6c3-9465d2ab073d","type":"PanTool"},{"id":"bd3b9e87-d835-42ee-a1d5-f73ee098453e","type":"WheelZoomTool"},{"id":"e629ec89-89b4-4bcc-9e4f-1ae106f55dc5","type":"BoxZoomTool"},{"id":"7e376623-be1e-4c48-aa77-d2fe56c72038","type":"PreviewSaveTool"},{"id":"e7ddcef9-d2ef-4cdc-9c74-f71a56dbf19a","type":"ResizeTool"},{"id":"b337eaba-ceb8-48e3-b9c3-7cb82a391c38","type":"ResetTool"},{"id":"97a8a74a-fc03-4610-a8e1-238ad3a79474","type":"HelpTool"}],"x_range":{"id":"1f73a499-e429-48c0-a390-6df422b2a381","type":"DataRange1d"},"y_range":{"id":"47215fb2-8b8f-4c4b-85dd-ddbc1e3f5e1a","type":"DataRange1d"}},"id":"36e86813-d472-4edf-825d-27c75d36780c","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"8248eaa3-771d-4c9b-96c6-feed34a378bd","subtype":"Figure","type":"Plot"},"ticker":{"id":"1332d7c7-2861-4b2d-8cb9-881937dc2696","type":"BasicTicker"}},"id":"e9013563-7d1c-4a2e-982d-a6cb37b8e2d3","type":"Grid"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"50fe7b4d-fff8-4452-9679-2e07c19ec102","type":"Line"},{"attributes":{"plot":{"id":"d10b9831-165b-4bbb-89be-468eda94b454","subtype":"Figure","type":"Plot"}},"id":"7b090fb6-3f13-4a0a-8e79-c846ca212991","type":"ResetTool"},{"attributes":{"callback":null},"id":"dcdcc9fc-339b-4602-9f2b-1149062e6c6f","type":"DataRange1d"},{"attributes":{"formatter":{"id":"d1b68d87-a7dd-45eb-a597-03831aa048fb","type":"BasicTickFormatter"},"plot":{"id":"6eda9c7b-291d-4805-9765-1b14e5622e20","subtype":"Figure","type":"Plot"},"ticker":{"id":"cbe5bad5-e0bb-42a9-955a-a32e67707e7d","type":"BasicTicker"}},"id":"2a4b7edb-94d2-44e4-8e83-d202e56 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
interact(update,k=(0,t_len-1))

# %% [markdown]
# ### Derivative initial condition

# %%
(u,x,t)=w_solve3(.5,dx,dt,3*t_len,0*triangle,1*triangle)

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert solution, Der Cond", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="dcb66da6-f985-494c-8cc6-6108229e224a"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dcb66da6-f985-494c-8cc6-6108229e224a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dcb66da6-f985-494c-8cc6-6108229e224a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"74778295-c04b-43cb-bf2b-3f5158c71a9a":{"roots":{"references":[{"attributes":{},"id":"55f51a52-c509-497f-ab78-b1e9f9300f8a","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"}],"left":[{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"},{"id":"eb77c811-1f61-476b-9105-8401de78f623","type":"Grid"},{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"},{"id":"b133c9df-ff4f-4a0e-98d9-50ee2d6896b6","type":"Grid"},{"id":"c923bdde-af78-48d2-91e2-a81dc8736ef7","type":"BoxAnnotation"},{"id":"66e93b08-0b45-45bf-adac-003a5a1d6a12","type":"GlyphRenderer"}],"title":"F.D. Explicit method solution, Der Cond","tool_events":{"id":"485f0e5e-668f-4ef6-865f-285602775e83","type":"ToolEvents"},"tools":[{"id":"c2b65358-025c-4bf6-aabc-00cee0abdaeb","type":"PanTool"},{"id":"91eb13c8-c357-4074-bda2-a1cfdf4e8c34","type":"WheelZoomTool"},{"id":"da5b6def-13d3-46f8-b904-0334e5f71b49","type":"BoxZoomTool"},{"id":"6eaedf4d-b2fa-415c-93c7-23afd8c89b87","type":"PreviewSaveTool"},{"id":"a28aa9da-b4a1-43ec-bc3b-fd8a0c6da294","type":"ResizeTool"},{"id":"98a32f87-afd0-4d74-a861-2e55d4b274d6","type":"ResetTool"},{"id":"cf989ecf-c843-4c0f-913e-91e10b532f5c","type":"HelpTool"}],"x_range":{"id":"9b387751-84ba-45c8-ae1e-3e909d3f6992","type":"DataRange1d"},"y_range":{"id":"90cf8f09-5564-4c89-abc9-e0fc72d92e58","type":"DataRange1d"}},"id":"89bbc7d4-b1c9-4113-b2f9-7acfc6c5e5d5","subtype":"Figure","type":"Plot"},{"attributes":{"below":[{"id":"62a9cd46-4e62-4994-9e85-6b1833e1ba60","type":"LinearAxis"}],"left":[{"id":"fae36daf-1052-434a-be5c-38330d9ebcc4","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"62a9cd46-4e62-4994-9e85-6b1833e1ba60","type":"LinearAxis"},{"id":"6f6251b6-9a57-4686-b0dd-10bd4bbe6a13","type":"Grid"},{"id":"fae36daf-1052-434a-be5c-38330d9ebcc4","type":"LinearAxis"},{"id":"adc72504-a97b-493f-8593-d0c578b97c70","type":"Grid"},{"id":"fe4a382f-9e6e-42d2-a5fa-ea457f3f54af","type":"BoxAnnotation"},{"id":"0d671bfc-8823-4125-afb4-4d55c5830c7f","type":"GlyphRenderer"}],"title":"Implicit solution method, Der cond","tool_events":{"id":"7e7cc00d-c9a1-468a-acd7-edcc91e8df7b","type":"ToolEvents"},"tools":[{"id":"55a167b1-e8ab-4d8b-b6c3-9465d2ab073d","type":"PanTool"},{"id":"bd3b9e87-d835-42ee-a1d5-f73ee098453e","type":"WheelZoomTool"},{"id":"e629ec89-89b4-4bcc-9e4f-1ae106f55dc5","type":"BoxZoomTool"},{"id":"7e376623-be1e-4c48-aa77-d2fe56c72038","type":"PreviewSaveTool"},{"id":"e7ddcef9-d2ef-4cdc-9c74-f71a56dbf19a","type":"ResizeTool"},{"id":"b337eaba-ceb8-48e3-b9c3-7cb82a391c38","type":"ResetTool"},{"id":"97a8a74a-fc03-4610-a8e1-238ad3a79474","type":"HelpTool"}],"x_range":{"id":"1f73a499-e429-48c0-a390-6df422b2a381","type":"DataRange1d"},"y_range":{"id":"47215fb2-8b8f-4c4b-85dd-ddbc1e3f5e1a","type":"DataRange1d"}},"id":"36e86813-d472-4edf-825d-27c75d36780c","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"8248eaa3-771d-4c9b-96c6-feed34a378bd","subtype":"Figure","type":"Plot"},"ticker":{"id":"1332d7c7-2861-4b2d-8cb9-881937dc2696","type":"BasicTicker"}},"id":"e9013563-7d1c-4a2e-982d-a6cb37b8e2d3","type":"Grid"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"50fe7b4d-fff8-4452-9679-2e07c19ec102","type":"Line"},{"attributes":{"plot":{"id":"d10b9831-165b-4bbb-89be-468eda94b454","subtype":"Figure","type":"Plot"}},"id":"7b090fb6-3f13-4a0a-8e79-c846ca212991","type":"ResetTool"},{"attributes":{"callback":null},"id":"dcdcc9fc-339b-4602-9f2b-1149062e6c6f","type":"DataRange1d"},{"attributes":{"formatter":{"id":"d1b68d87-a7dd-45eb-a597-03831aa048fb","type":"BasicTickFormatter"},"plot":{"id":"6eda9c7b-291d-4805-9765-1b14e5622e20","subtype":"Figure","type":"Plot"},"ticker":{"id":"cbe5bad5-e0bb-42a9-955a-a32e67707e7d","type":"BasicTicker"}},"id":"2a4b7edb-94d2-44e4-8e83-d202e56 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
interact(update,k=(0,3*t_len-1))

# %% [markdown]
# # Comparing solutions
#
# In principle, we want these different solution methods to be directly comparable.
#
# So let's try this out, by computing the difference of two solution.
#
# Here we compare the explicit f.d. method with d'Alambert's method.

# %%
(u_exp,x,t)=w_solve1(.5,dx,dt,t_len,1*triangle,0*triangle)
(u_dal,x,t)=w_solve3(.5,dx,dt,t_len,1*triangle,0*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert minus explicit", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")

def update(k=0):
    src.data['y']=u_dal[:,k]-u_exp[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="c5722537-6662-4d89-92eb-1d9576fddcd4"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c5722537-6662-4d89-92eb-1d9576fddcd4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c5722537-6662-4d89-92eb-1d9576fddcd4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"26ecb91a-5ebf-4bab-93fd-12fed26bfd24":{"roots":{"references":[{"attributes":{"line_color":{"value":"#2222aa"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3df2a510-54ae-4cf0-986b-ab3a529e6e0a","type":"Line"},{"attributes":{},"id":"55f51a52-c509-497f-ab78-b1e9f9300f8a","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"}],"left":[{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"},{"id":"eb77c811-1f61-476b-9105-8401de78f623","type":"Grid"},{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"},{"id":"b133c9df-ff4f-4a0e-98d9-50ee2d6896b6","type":"Grid"},{"id":"c923bdde-af78-48d2-91e2-a81dc8736ef7","type":"BoxAnnotation"},{"id":"66e93b08-0b45-45bf-adac-003a5a1d6a12","type":"GlyphRenderer"}],"title":"F.D. Explicit method solution, Der Cond","tool_events":{"id":"485f0e5e-668f-4ef6-865f-285602775e83","type":"ToolEvents"},"tools":[{"id":"c2b65358-025c-4bf6-aabc-00cee0abdaeb","type":"PanTool"},{"id":"91eb13c8-c357-4074-bda2-a1cfdf4e8c34","type":"WheelZoomTool"},{"id":"da5b6def-13d3-46f8-b904-0334e5f71b49","type":"BoxZoomTool"},{"id":"6eaedf4d-b2fa-415c-93c7-23afd8c89b87","type":"PreviewSaveTool"},{"id":"a28aa9da-b4a1-43ec-bc3b-fd8a0c6da294","type":"ResizeTool"},{"id":"98a32f87-afd0-4d74-a861-2e55d4b274d6","type":"ResetTool"},{"id":"cf989ecf-c843-4c0f-913e-91e10b532f5c","type":"HelpTool"}],"x_range":{"id":"9b387751-84ba-45c8-ae1e-3e909d3f6992","type":"DataRange1d"},"y_range":{"id":"90cf8f09-5564-4c89-abc9-e0fc72d92e58","type":"DataRange1d"}},"id":"89bbc7d4-b1c9-4113-b2f9-7acfc6c5e5d5","subtype":"Figure","type":"Plot"},{"attributes":{"below":[{"id":"62a9cd46-4e62-4994-9e85-6b1833e1ba60","type":"LinearAxis"}],"left":[{"id":"fae36daf-1052-434a-be5c-38330d9ebcc4","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"62a9cd46-4e62-4994-9e85-6b1833e1ba60","type":"LinearAxis"},{"id":"6f6251b6-9a57-4686-b0dd-10bd4bbe6a13","type":"Grid"},{"id":"fae36daf-1052-434a-be5c-38330d9ebcc4","type":"LinearAxis"},{"id":"adc72504-a97b-493f-8593-d0c578b97c70","type":"Grid"},{"id":"fe4a382f-9e6e-42d2-a5fa-ea457f3f54af","type":"BoxAnnotation"},{"id":"0d671bfc-8823-4125-afb4-4d55c5830c7f","type":"GlyphRenderer"}],"title":"Implicit solution method, Der cond","tool_events":{"id":"7e7cc00d-c9a1-468a-acd7-edcc91e8df7b","type":"ToolEvents"},"tools":[{"id":"55a167b1-e8ab-4d8b-b6c3-9465d2ab073d","type":"PanTool"},{"id":"bd3b9e87-d835-42ee-a1d5-f73ee098453e","type":"WheelZoomTool"},{"id":"e629ec89-89b4-4bcc-9e4f-1ae106f55dc5","type":"BoxZoomTool"},{"id":"7e376623-be1e-4c48-aa77-d2fe56c72038","type":"PreviewSaveTool"},{"id":"e7ddcef9-d2ef-4cdc-9c74-f71a56dbf19a","type":"ResizeTool"},{"id":"b337eaba-ceb8-48e3-b9c3-7cb82a391c38","type":"ResetTool"},{"id":"97a8a74a-fc03-4610-a8e1-238ad3a79474","type":"HelpTool"}],"x_range":{"id":"1f73a499-e429-48c0-a390-6df422b2a381","type":"DataRange1d"},"y_range":{"id":"47215fb2-8b8f-4c4b-85dd-ddbc1e3f5e1a","type":"DataRange1d"}},"id":"36e86813-d472-4edf-825d-27c75d36780c","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"8248eaa3-771d-4c9b-96c6-feed34a378bd","subtype":"Figure","type":"Plot"},"ticker":{"id":"1332d7c7-2861-4b2d-8cb9-881937dc2696","type":"BasicTicker"}},"id":"e9013563-7d1c-4a2e-982d-a6cb37b8e2d3","type":"Grid"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"50fe7b4d-fff8-4452-9679-2e07c19ec102","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011,0.012,0.013000000000000001,0.014,0.015,0.016,0.017,0.018000000000000002,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026000000000000002,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036000000000000004,0.037,0.038,0.039,0.04,0.041,0.042,0.043000000000000 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
interact(update,k=(0,t_len-1))

# %% [markdown]
# ## A moving wavefront
#
# Let's try an actual wave. We want something like
# $$u(x,t) = \exp(-(x -x_a-ct)^2/w^2), $$
# where $x_a$ is the center of the Gaussian at $t=0$, $w$ is the width of the Gaussian, $c$ is the velocity of the wave.
#
# This gives
# $$u_0(x) = \exp(-(x -x_a)^2/w^2) \\
#   u_1(x) = \frac{2c(x-x_a)}{w^2}\exp(-(x -x_a)^2/w^2) = \frac{2c(x-x_a)}{w^2}u_0(x).$$

# %%
c = .707  # velocity
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
u0 = np.exp(-(x-.5)*(x-.5)/.01)
u1 = 2*c*u0*(x-.5)/.01

# %%
(u,x,t)=w_solve3(c*c,dx,dt,t_len,u0,u1)  # notice we input the velocity squared!

# %%
y=u[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))
p = figure(title="Moving wave", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")

def update(k=0):
    src.data['y']=u[:,k]
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="7de44693-a3aa-45c4-b54e-4900fa396707"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7de44693-a3aa-45c4-b54e-4900fa396707");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7de44693-a3aa-45c4-b54e-4900fa396707' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cf6c2283-7ada-4904-b4e3-7353a75468fb":{"roots":{"references":[{"attributes":{"line_color":{"value":"#2222aa"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3df2a510-54ae-4cf0-986b-ab3a529e6e0a","type":"Line"},{"attributes":{},"id":"55f51a52-c509-497f-ab78-b1e9f9300f8a","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"a235b1ce-4c11-4410-9656-44f6c91d410c","type":"BasicTickFormatter"},"plot":{"id":"2ffde812-5923-42a8-a82c-89d986a84dc5","subtype":"Figure","type":"Plot"},"ticker":{"id":"4e1907ff-770d-4b9c-a7e6-fb6c3d1dc0c4","type":"BasicTicker"}},"id":"37ad711e-0420-4fbd-8cc7-141035a75b2e","type":"LinearAxis"},{"attributes":{"below":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"}],"left":[{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"5304777f-7ef6-4165-aba7-f07642b851ab","type":"LinearAxis"},{"id":"eb77c811-1f61-476b-9105-8401de78f623","type":"Grid"},{"id":"bfe33d04-286e-452b-b0eb-d0ae62c683bf","type":"LinearAxis"},{"id":"b133c9df-ff4f-4a0e-98d9-50ee2d6896b6","type":"Grid"},{"id":"c923bdde-af78-48d2-91e2-a81dc8736ef7","type":"BoxAnnotation"},{"id":"66e93b08-0b45-45bf-adac-003a5a1d6a12","type":"GlyphRenderer"}],"title":"F.D. Explicit method solution, Der Cond","tool_events":{"id":"485f0e5e-668f-4ef6-865f-285602775e83","type":"ToolEvents"},"tools":[{"id":"c2b65358-025c-4bf6-aabc-00cee0abdaeb","type":"PanTool"},{"id":"91eb13c8-c357-4074-bda2-a1cfdf4e8c34","type":"WheelZoomTool"},{"id":"da5b6def-13d3-46f8-b904-0334e5f71b49","type":"BoxZoomTool"},{"id":"6eaedf4d-b2fa-415c-93c7-23afd8c89b87","type":"PreviewSaveTool"},{"id":"a28aa9da-b4a1-43ec-bc3b-fd8a0c6da294","type":"ResizeTool"},{"id":"98a32f87-afd0-4d74-a861-2e55d4b274d6","type":"ResetTool"},{"id":"cf989ecf-c843-4c0f-913e-91e10b532f5c","type":"HelpTool"}],"x_range":{"id":"9b387751-84ba-45c8-ae1e-3e909d3f6992","type":"DataRange1d"},"y_range":{"id":"90cf8f09-5564-4c89-abc9-e0fc72d92e58","type":"DataRange1d"}},"id":"89bbc7d4-b1c9-4113-b2f9-7acfc6c5e5d5","subtype":"Figure","type":"Plot"},{"attributes":{"below":[{"id":"62a9cd46-4e62-4994-9e85-6b1833e1ba60","type":"LinearAxis"}],"left":[{"id":"fae36daf-1052-434a-be5c-38330d9ebcc4","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"62a9cd46-4e62-4994-9e85-6b1833e1ba60","type":"LinearAxis"},{"id":"6f6251b6-9a57-4686-b0dd-10bd4bbe6a13","type":"Grid"},{"id":"fae36daf-1052-434a-be5c-38330d9ebcc4","type":"LinearAxis"},{"id":"adc72504-a97b-493f-8593-d0c578b97c70","type":"Grid"},{"id":"fe4a382f-9e6e-42d2-a5fa-ea457f3f54af","type":"BoxAnnotation"},{"id":"0d671bfc-8823-4125-afb4-4d55c5830c7f","type":"GlyphRenderer"}],"title":"Implicit solution method, Der cond","tool_events":{"id":"7e7cc00d-c9a1-468a-acd7-edcc91e8df7b","type":"ToolEvents"},"tools":[{"id":"55a167b1-e8ab-4d8b-b6c3-9465d2ab073d","type":"PanTool"},{"id":"bd3b9e87-d835-42ee-a1d5-f73ee098453e","type":"WheelZoomTool"},{"id":"e629ec89-89b4-4bcc-9e4f-1ae106f55dc5","type":"BoxZoomTool"},{"id":"7e376623-be1e-4c48-aa77-d2fe56c72038","type":"PreviewSaveTool"},{"id":"e7ddcef9-d2ef-4cdc-9c74-f71a56dbf19a","type":"ResizeTool"},{"id":"b337eaba-ceb8-48e3-b9c3-7cb82a391c38","type":"ResetTool"},{"id":"97a8a74a-fc03-4610-a8e1-238ad3a79474","type":"HelpTool"}],"x_range":{"id":"1f73a499-e429-48c0-a390-6df422b2a381","type":"DataRange1d"},"y_range":{"id":"47215fb2-8b8f-4c4b-85dd-ddbc1e3f5e1a","type":"DataRange1d"}},"id":"36e86813-d472-4edf-825d-27c75d36780c","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"8248eaa3-771d-4c9b-96c6-feed34a378bd","subtype":"Figure","type":"Plot"},"ticker":{"id":"1332d7c7-2861-4b2d-8cb9-881937dc2696","type":"BasicTicker"}},"id":"e9013563-7d1c-4a2e-982d-a6cb37b8e2d3","type":"Grid"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"50fe7b4d-fff8-4452-9679-2e07c19ec102","type":"Line"},{"attributes":{"callback":null},"id":"873d8a33-23b1-4800-89c2-06ba4aa52c0b","type":"DataRang ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
interact(update,k=(0,t_len-1))

# %% [markdown]
# ## Some dangerout code
#
# For the record, here is some code I wrote that did live animations and 2D displays.
#
# However, it seems to bread our Jupyter Hub, perhaps because Bokeh can't handle these large amounts of data.

# %%
## Initial setup
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# %%
# Here we solve the wave equation, with initial position $u(x,0)$ set to the triangle waveform
(u,x,t)=w_solve1(.5,dx,dt,t_len,triangle,0*triangle)
# Out:
# CFL value is  0.707106781187

# %%
y=triangle
src = ColumnDataSource(data=dict(x=x,y=y))
p = figure(title="Finite difference, explicit method", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=1,source=src,name="foo")
show(p)
# Out:
#     <div class="plotdiv" id="f6516221-5885-4888-b834-29e656685f16"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f6516221-5885-4888-b834-29e656685f16");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f6516221-5885-4888-b834-29e656685f16' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d2c6e9f6-4ae1-49bb-a49c-a1231e40a2e9":{"roots":{"references":[{"attributes":{"line_color":{"value":"#2222aa"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3df2a510-54ae-4cf0-986b-ab3a529e6e0a","type":"Line"},{"attributes":{"formatter":{"id":"c1cdd598-7eee-4b52-85a8-c7d8c15c976a","type":"BasicTickFormatter"},"plot":{"id":"172113ac-8daa-437e-9b41-41ec2ff43c02","subtype":"Figure","type":"Plot"},"ticker":{"id":"8b3deff5-09f4-4e62-9eba-461956d2ceee","type":"BasicTicker"}},"id":"e61de4b8-0668-47d8-80f8-9e74442ee724","type":"LinearAxis"},{"attributes":{"below":[{"id":"62a9cd46-4e62-4994-9e85-6b1833e1ba60","type":"LinearAxis"}],"left":[{"id":"fae36daf-1052-434a-be5c-38330d9ebcc4","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"62a9cd46-4e62-4994-9e85-6b1833e1ba60","type":"LinearAxis"},{"id":"6f6251b6-9a57-4686-b0dd-10bd4bbe6a13","type":"Grid"},{"id":"fae36daf-1052-434a-be5c-38330d9ebcc4","type":"LinearAxis"},{"id":"adc72504-a97b-493f-8593-d0c578b97c70","type":"Grid"},{"id":"fe4a382f-9e6e-42d2-a5fa-ea457f3f54af","type":"BoxAnnotation"},{"id":"0d671bfc-8823-4125-afb4-4d55c5830c7f","type":"GlyphRenderer"}],"title":"Implicit solution method, Der cond","tool_events":{"id":"7e7cc00d-c9a1-468a-acd7-edcc91e8df7b","type":"ToolEvents"},"tools":[{"id":"55a167b1-e8ab-4d8b-b6c3-9465d2ab073d","type":"PanTool"},{"id":"bd3b9e87-d835-42ee-a1d5-f73ee098453e","type":"WheelZoomTool"},{"id":"e629ec89-89b4-4bcc-9e4f-1ae106f55dc5","type":"BoxZoomTool"},{"id":"7e376623-be1e-4c48-aa77-d2fe56c72038","type":"PreviewSaveTool"},{"id":"e7ddcef9-d2ef-4cdc-9c74-f71a56dbf19a","type":"ResizeTool"},{"id":"b337eaba-ceb8-48e3-b9c3-7cb82a391c38","type":"ResetTool"},{"id":"97a8a74a-fc03-4610-a8e1-238ad3a79474","type":"HelpTool"}],"x_range":{"id":"1f73a499-e429-48c0-a390-6df422b2a381","type":"DataRange1d"},"y_range":{"id":"47215fb2-8b8f-4c4b-85dd-ddbc1e3f5e1a","type":"DataRange1d"}},"id":"36e86813-d472-4edf-825d-27c75d36780c","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"8248eaa3-771d-4c9b-96c6-feed34a378bd","subtype":"Figure","type":"Plot"},"ticker":{"id":"1332d7c7-2861-4b2d-8cb9-881937dc2696","type":"BasicTicker"}},"id":"e9013563-7d1c-4a2e-982d-a6cb37b8e2d3","type":"Grid"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"50fe7b4d-fff8-4452-9679-2e07c19ec102","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011,0.012,0.013000000000000001,0.014,0.015,0.016,0.017,0.018000000000000002,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026000000000000002,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036000000000000004,0.037,0.038,0.039,0.04,0.041,0.042,0.043000000000000003,0.044,0.045,0.046,0.047,0.048,0.049,0.05,0.051000000000000004,0.052000000000000005,0.053,0.054,0.055,0.056,0.057,0.058,0.059000000000000004,0.06,0.061,0.062,0.063,0.064,0.065,0.066,0.067,0.068,0.069,0.07,0.07100000000000001,0.07200000000000001,0.073,0.074,0.075,0.076,0.077,0.078,0.079,0.08,0.081,0.082,0.083,0.084,0.085,0.08600000000000001,0.08700000000000001,0.088,0.089,0.09,0.091,0.092,0.093,0.094,0.095,0.096,0.097,0.098,0.099,0.1,0.101,0.10200000000000001,0.10300000000000001,0.10400000000000001,0.105,0.106,0.107,0.108,0.109,0.11,0.111,0.112,0.113,0.114,0.115,0.116,0.117,0.11800000000000001,0.11900000000000001,0.12,0.121,0.122,0.123,0.124,0.125,0.126,0.127,0.128,0.129,0.13,0.131,0.132,0.133,0.134,0.135,0.136,0.137,0.138,0.139,0.14,0.14100000000000001,0.14200000000000002,0.14300000000000002,0.14400000000000002,0.145,0.146,0.147,0.148,0.149,0.15,0.151,0.152,0.153,0.154,0.155,0.156,0.157,0.158,0.159,0.16,0.161,0.162,0.163,0.164,0.165,0.166,0.167,0.168,0.169,0.17,0.171,0.17200000000000001,0.17300000000000001,0.17400000000000002,0.17500000000000002,0.176,0.177,0.178,0.179,0.18,0.181,0.182,0.183,0.184,0.185,0.186,0.187,0.188,0.189,0.19,0.191,0.192,0.193,0.194,0.195,0.19 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
# WARNING. This creates a lot of data, may swamp the CPU. 
# This runs an animation, to view the wave as it propogates
for k in range(t_len):
    src.data['y'] = u[:,k]
    push_notebook()

# %%
# WARNING: This cell will make everything else run slow, and may crash Jupyter!!!
p = figure(x_range=(0, 1), y_range=(0, 1))
p.image(image=[u.transpose()], x=0, y=0, dw=1, dh=1, palette="Spectral11")
show(p)
