# %% [markdown]
# # WaveSolver - 1D
# M. Lamoureux May 31, 2016. Pacific Insitute for the Mathematical Sciences. Updated June 15, 2016.
#
# ## Demo notes.
# Run "All Cells" then look at the last graph at the bottom. The slides will control various numerical solutions to the wave equation. So if you don't want to read all the section, you can just see the end results at the bottom.
#
# You can also examine each section individual, if you want to understand the numeric behind solving the one-dimensional wave equation (with constant coefficients). Becuase of a quirk in Boken, you have to run the cell with the plot, followed by the cell with the slider, in order to get each plot to work individually.
#
# This was also written as a test of how far we can push Bokeh and the Jupyter Hub in making some calculations and graphics.
#
# ## Math notes
# We have three examples of a numerical solver for the one dimensional wave equation:
# - explicit finite difference
# - implicit finite difference
# - D'Alembert's exact solution.
#
# In the demo, we show solutions for an initial position of  a triangular bump, then for an initial particle velocity of a triangular bump, and finally we compare the exact solution (d'Alembert) to the finite difference code. For fun, we also show how a moving Gaussian propagates.

# %% [markdown]
# ## Introduction to the 1D wave equation.
#
# The basic idea is to represent the vibrations of a (horizonal) string under tension by a function $u(x,t)$ where $x$ is the horizontal displacement along the string, $t$ is the time parameter, and $y=u(x,t)$ indicates the (vertical) displacement of the string at point $x$ along the string, at time $t$
#
# A typical wave would look something like
# $$u(x,t) = \sin(x-ct)$$
# which represents a sinusoidal wave moving to the right at velocity $c$.
#
# From Newon's law of motion (mass times acceleration equals force), we can derive the wave equation for the string in the form
# $$ \rho \cdot u_{tt} = k \cdot u_{xx}$$
# where $\rho$ is a mass density, $u_{tt}$ is an acceleration (the second derivative w.r.t. time), $k$ is the modulus of elasticity and $u_{xx}$ is a measure of curvature (the second derivative w.r.t. $x$), causing the bending force.
#
# Including boundary and initial conditions, while setting the parameter $c^2 = k/\rho$, we obtain the usual 1D wave equation on an interval as this:
#
#
# $$u_{tt} = c^2 u_{xx} \mbox{ on interval } [x_0,x_1]$$
# subject to boundary conditions
# $$u(x_0,t) = u(x_1, t) = 0 \mbox{ for all $t$. }$$
# and initial conditions
# $$u(x,0) = u_0(x), \quad u_t(x,t) = u_1(x) \mbox{ on interval } [x_0,x_1].$$
#
#
# Let's write some PDE solvers for this 1D wave equation.
#
# Start with some simple solvers, then get more complex.
#
# The function to solve the PDE needs to know $c^2, u_0, u_1$, the sampling intervals $dx$ and $dt$, and the number of time steps to execute. Everything else can be inferred from those inputs. The output should be a 2D array, indexed in x and t steps.
#
# Maybe we could actually output the solution $u(x,t)$ as well as the vector of indices for $x$ and $t$.

# %% [markdown]
# ## Software tools
# We import some tools for numerical work (NumPy, SciPy), plotting (Boken), and an interactive widget. We are using Boken because it is faster than matplotlib. Note, however, that Boken seems to be heavy on memory usage.
#
# You can read about the interactive widgets here: http://bokeh.pydata.org/en/0.10.0/_images/notebook_interactors.png

# %%
import numpy as np
from scipy.linalg import solve_toeplitz  # a matrix equation solver
from scipy.integrate import cumtrapz # a numerical integrator, using trapezoid rule
from bokeh.models import ColumnDataSource
from bokeh.plotting import *
from bokeh.io import push_notebook
from ipywidgets import interact, IntSlider

# %% [markdown]
# We need to initialize the Bokeh plotting methods with the following.

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4e158602-d7ac-43d5-bd69-9844ec44da71">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Explicit method of solution in finite differences
#
# The finite difference method is probably the most common numerical method for solving PDEs. The derivatives are approximated by Newton difference ratios, and you step through in time to progress the solution from $t=0$ to some ending time.
#
# The following defines a function that solves the wave equation, using an explicit finite difference method. We follow the notes in the referenced book by Myint-U and Debnath.
#
# The differencing in spatial variable $x$ is done by a convolution, as this will be fast.
#
# We print out the value of the CFL constant as a sanity check. The method is stable and convergent provided the CFL value is less than one. (This means $dt$ needs to be small enough.) See the book for details.
#
# The input parameters are velocity squared $c2$, spatial step size $dx$, temporal step size $dt$, number of time steps $t$_$len$, initial position $u0$ and initial velocity $u1$. $u0$ and $u1$ are arrays of some length $N$, which the code will use to deduce everything it needs to know.
#
# I tend to think of these as dimensionless variables, but you can use real physical values if you like, so long as you are consistent. For instance $dx$ in meters, $dt$ in seconds, and $c2$ in (meters/second) squared.

# %%
# Based on Section 14.4 in Myint-U and Debnath's book
def w_solve1(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    e2 = c2*dt*dt/(dx*dx)  # Courant parameter squared (test for convergence!)
    print("CFL value is ",np.sqrt(e2))
    kern = np.array([e2, 2*(1-e2), e2]) # the convolution kernel we need for laplacian solver
    u[:,0] = u0            # t=0 initial condition
    u[:,1] = np.convolve(u0,kern/2)[1:x_len+1] + dt*u1 # t=0 derivative condition, eqn 14.4.6
    for j in range(2,t_len):
        u[:,j] = np.convolve(u[:,j-1],kern)[1:x_len+1] - u[:,j-2] # eqn 14.4.3
    # let's produce the x and t vectors, in case we need them
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    return u,x,t

# %% [markdown]
# ### First example
# We do 1000 steps in time and space, using a triangular waveform for the initial values. We then call the wave equation solver. Finally, we set up Bokeh to plot the answers for us.

# %%
# Define the initial parameters, including a triangular waveform
c2 = .5  # velocity squared
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# Here we solve the wave equation, with initial position $u(x,0)$ set to the triangle waveform
(u_exp,x,t)=w_solve1(c2,dx,dt,t_len,triangle,0*triangle)

# And now we plot the result, using Bokeh as our plotting method

y=u_exp[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="FD Explicit method solution", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_exp(k=0):
    src.data['y']=u_exp[:,k]
    p.title="FD Explicit method solution"
    push_notebook()

show(p)
# Out:
# CFL value is  0.707106781187
#     <div class="plotdiv" id="70a8e9ad-aa69-4fad-bb70-10d9c259db11"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("70a8e9ad-aa69-4fad-bb70-10d9c259db11");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '70a8e9ad-aa69-4fad-bb70-10d9c259db11' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5c05cfb5-ff95-46a2-b86d-67d1619e2ed5":{"roots":{"references":[{"attributes":{"plot":{"id":"765d224a-fc83-465c-8c45-9f1c9d5646f1","subtype":"Figure","type":"Plot"}},"id":"79476239-05ea-4be5-94ed-b65c2dfc3200","type":"PreviewSaveTool"},{"attributes":{"overlay":{"id":"052396fd-ff44-4301-b46f-62bfaa590b7d","type":"BoxAnnotation"},"plot":{"id":"76316385-8e5f-4166-9476-656e92cd4815","subtype":"Figure","type":"Plot"}},"id":"71dbdb6c-ca2a-4fb5-9937-f6e5049b6f2d","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"b584b9ac-c1cc-4b40-b8c0-da3a752d3b97","type":"Line"},{"attributes":{"below":[{"id":"04357017-a686-4f75-b979-e662499b542f","type":"LinearAxis"}],"left":[{"id":"6973fae1-6087-4736-a778-413e7066cb88","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"04357017-a686-4f75-b979-e662499b542f","type":"LinearAxis"},{"id":"ff9d143d-5fd8-4c8a-b3e6-ad99078d1a5b","type":"Grid"},{"id":"6973fae1-6087-4736-a778-413e7066cb88","type":"LinearAxis"},{"id":"008e6920-c5cc-4516-ab8a-689cb30a79f1","type":"Grid"},{"id":"a3008231-dd7c-40e3-ad20-36363ec414dc","type":"BoxAnnotation"},{"id":"a68537bc-6753-417c-b3a5-2372bb8bc21b","type":"GlyphRenderer"}],"title":"FD Explicit method, init velocity","tool_events":{"id":"b0132a12-4983-46fc-b2a0-339eae97454f","type":"ToolEvents"},"tools":[{"id":"e5f8ab64-7a38-4735-a4cc-fac726899e15","type":"PanTool"},{"id":"838dfda6-5131-42b1-9480-de44314b6440","type":"WheelZoomTool"},{"id":"ce70693f-33f2-41af-8c14-0050781b7b51","type":"BoxZoomTool"},{"id":"812fe520-5b29-4224-9c0a-3f452a552069","type":"PreviewSaveTool"},{"id":"daa0e841-b471-423e-b83a-c6c117aea3df","type":"ResizeTool"},{"id":"464b24ac-80e2-4294-96c3-d1390d53fd21","type":"ResetTool"},{"id":"d18366f5-8214-459d-b34d-9330f84973ad","type":"HelpTool"}],"x_range":{"id":"30c5f78e-c9d5-4ccc-b8dc-22904000a45a","type":"DataRange1d"},"y_range":{"id":"45b57b8b-09cf-42af-94fd-1ddf4479cad6","type":"DataRange1d"}},"id":"850acc19-ac98-4c66-b860-0c4d8a37d33e","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"0d1775ac-8e4b-435f-bd88-c12ffef0e22c","type":"BoxAnnotation"},"plot":{"id":"fa8a7a93-6c7a-44cf-8f1c-be0f7107b488","subtype":"Figure","type":"Plot"}},"id":"aeaf2c15-3210-4eed-9b76-eb012d20ad77","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7f6a0971-01b1-498a-9cdf-e05eb313ebf4","type":"Line"},{"attributes":{"plot":{"id":"76316385-8e5f-4166-9476-656e92cd4815","subtype":"Figure","type":"Plot"},"ticker":{"id":"7d90183a-79c1-408d-9579-1451042045cf","type":"BasicTicker"}},"id":"f8797382-594d-4dab-90e7-2831401c2e5e","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"0fde2ebb-c5c2-4c4d-8424-73fa64a3bd5c","type":"Line"},{"attributes":{},"id":"739111fb-fa96-4712-bd09-d825c8b050af","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"765d224a-fc83-465c-8c45-9f1c9d5646f1","subtype":"Figure","type":"Plot"},"ticker":{"id":"0002ab20-f4a5-444e-a5b9-7b741f1f99a0","type":"BasicTicker"}},"id":"b8f9254d-29f8-497d-965e-f3dc354ff688","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a3008231-dd7c-40e3-ad20-36363ec414dc","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"76316385-8e5f-4166-9476-656e92cd4815","subtype":"Figure","type":"Plot"}},"id":"f157eb4d-9f62-441b-96d8-af6dde673309","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>

# %%
# We have to call up the slider in a separate cell
interact(update_exp,k=(0,t_len-1))

# %% [markdown]
# ### Second example
# As above, but we use the triangular waveform for the initial particle velocities. We take 3000 time steps, because the veolocity initial condition is a bit unusual, and we want to really see what is going on.

# %%
# Define the initial parameters, including a triangular waveform
c2 = .5  # velocity squared
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# We solve, but this time with the velocity $u_t$ initial condition equal to the triangle impulse. 3000 steps!
(u_expD,x,t)=w_solve1(.5,dx,dt,3*t_len,0*triangle,1*triangle)

# And now we plot the result, using Bokeh as our plotting method

y=u_expD[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="F.D. Explicit method, init velocity", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_expD(k=0):
    src.data['y']=u_expD[:,k]
    p.title="FD Explicit method, init velocity"
    push_notebook()

show(p)
# Out:
# CFL value is  0.707106781187
#     <div class="plotdiv" id="de11d841-25af-44cc-b972-1e8f2eb990c6"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("de11d841-25af-44cc-b972-1e8f2eb990c6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'de11d841-25af-44cc-b972-1e8f2eb990c6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b9a2af5d-2f45-4816-891d-a0d84096824a":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"fa8a7a93-6c7a-44cf-8f1c-be0f7107b488","subtype":"Figure","type":"Plot"},"ticker":{"id":"95abbb0e-4f95-49f5-9630-d108f2a4774e","type":"BasicTicker"}},"id":"624aeb53-9005-47c2-86bb-140a119dc364","type":"Grid"},{"attributes":{"below":[{"id":"5be2cfa9-bac4-4244-931e-ae927f151000","type":"LinearAxis"}],"left":[{"id":"c910b75d-89cb-4ef4-8808-c5801350382d","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"5be2cfa9-bac4-4244-931e-ae927f151000","type":"LinearAxis"},{"id":"6a7a65a4-6e27-445a-a2c8-9045537d899c","type":"Grid"},{"id":"c910b75d-89cb-4ef4-8808-c5801350382d","type":"LinearAxis"},{"id":"624aeb53-9005-47c2-86bb-140a119dc364","type":"Grid"},{"id":"0d1775ac-8e4b-435f-bd88-c12ffef0e22c","type":"BoxAnnotation"},{"id":"2d1fe055-358b-4a91-8ae4-9a9762087e60","type":"GlyphRenderer"}],"title":"FD Explicit method solution","tool_events":{"id":"3562c652-285d-435c-a579-074aa43e4690","type":"ToolEvents"},"tools":[{"id":"ca0646f8-39c7-4f06-af44-22e2fe64d6b8","type":"PanTool"},{"id":"a8ec17f3-475e-4133-a513-432d9188d2b2","type":"WheelZoomTool"},{"id":"aeaf2c15-3210-4eed-9b76-eb012d20ad77","type":"BoxZoomTool"},{"id":"7ee3a101-4ff0-4047-8232-7625a604ee8e","type":"PreviewSaveTool"},{"id":"14760bb5-51fa-44f9-8765-f09e65f33ac0","type":"ResizeTool"},{"id":"93d06beb-de03-4a24-8c0b-819b5fe9517e","type":"ResetTool"},{"id":"ecec5e2d-7486-483d-8a97-4fb637912d11","type":"HelpTool"}],"x_range":{"id":"32b144c8-93f0-4717-818c-4efebef54886","type":"DataRange1d"},"y_range":{"id":"f366eccb-7a9d-45fc-9c52-22f47b7157fc","type":"DataRange1d"}},"id":"fa8a7a93-6c7a-44cf-8f1c-be0f7107b488","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"850acc19-ac98-4c66-b860-0c4d8a37d33e","subtype":"Figure","type":"Plot"}},"id":"812fe520-5b29-4224-9c0a-3f452a552069","type":"PreviewSaveTool"},{"attributes":{"formatter":{"id":"426023c6-5c0c-49ec-a189-c8f6d77537f2","type":"BasicTickFormatter"},"plot":{"id":"850acc19-ac98-4c66-b860-0c4d8a37d33e","subtype":"Figure","type":"Plot"},"ticker":{"id":"79a82174-f6d6-41be-a198-3e4b485cf4c9","type":"BasicTicker"}},"id":"04357017-a686-4f75-b979-e662499b542f","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7f6a0971-01b1-498a-9cdf-e05eb313ebf4","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011,0.012,0.013000000000000001,0.014,0.015,0.016,0.017,0.018000000000000002,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026000000000000002,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036000000000000004,0.037,0.038,0.039,0.04,0.041,0.042,0.043000000000000003,0.044,0.045,0.046,0.047,0.048,0.049,0.05,0.051000000000000004,0.052000000000000005,0.053,0.054,0.055,0.056,0.057,0.058,0.059000000000000004,0.06,0.061,0.062,0.063,0.064,0.065,0.066,0.067,0.068,0.069,0.07,0.07100000000000001,0.07200000000000001,0.073,0.074,0.075,0.076,0.077,0.078,0.079,0.08,0.081,0.082,0.083,0.084,0.085,0.08600000000000001,0.08700000000000001,0.088,0.089,0.09,0.091,0.092,0.093,0.094,0.095,0.096,0.097,0.098,0.099,0.1,0.101,0.10200000000000001,0.10300000000000001,0.10400000000000001,0.105,0.106,0.107,0.108,0.109,0.11,0.111,0.112,0.113,0.114,0.115,0.116,0.117,0.11800000000000001,0.11900000000000001,0.12,0.121,0.122,0.123,0.124,0.125,0.126,0.127,0.128,0.129,0.13,0.131,0.132,0.133,0.134,0.135,0.136,0.137,0.138,0.139,0.14,0.14100000000000001,0.14200000000000002,0.14300000000000002,0.14400000000000002,0.145,0.146,0.147,0.148,0.149,0.15,0.151,0.152,0.153,0.154,0.155,0.156,0.157,0.158,0.159,0.16,0.161,0.162,0.163,0.164,0.165,0.166,0.167,0.168,0.169,0.17,0.171,0.17200000000000001,0.17300000000000001,0.17400000000000002,0.17500000000000002,0.176,0.177,0.178,0.179,0.18,0.181,0.182,0.183,0.184,0.185,0.186,0.187,0.188,0.189,0.19 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[6]</strong>&gt;</code></p>

# %%
# We have to call up the slider in a separate cell
interact(update_expD,k=(0,3*t_len-1))

# %% [markdown]
# ## Implicit method
#
# Here we try an implicit method for solving the wave equation. Again from Myint-U and Debnath's book, in Section 14.5, part (B) on Hyperbolic equations.
#
# We need to use scipy libraries as we have to solve a system of linear equation. In fact the system is tridiagonal and Toepliz, so this should be fast. I see how to use Toepliz in scipy, but I don't know how to tell it that the system is only tridiagonal. It should be possible to speed this up.

# %%
# Based on Section 14.5 (B) in Myint-U and Debnath's book
def w_solve2(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    e2 = c2*dt*dt/(dx*dx)  # Courant parameter squared (test for convergence!)
    print("CFL value is ",np.sqrt(e2))
    kern = np.array([e2, 2*(1-e2), e2]) # the convolution kernel we need for laplacian solver
    u[:,0] = u0            # t=0 initial condition
    u[:,1] = np.convolve(u0,kern/2)[1:x_len+1] + dt*u1 # t=0 derivative condition, eqn 14.4.6
    # Note the above is a cheat, we are using the explicit method to find u[:,1], Should do this implicitly
    kern2 = np.array([e2, -2*(1+e2), e2]) # the convolution kernel we need for implicit solver. It is different.
    toepk = np.zeros(x_len)  # this will hold the entries for the tridiagonal Toeplitz matrix
    toepk[0] = 2*(1+e2);
    toepk[1] = -e2
    for j in range(2,t_len):
        rhs = np.convolve(u[:,j-2],kern2)[1:x_len+1] + 4*u[:,j-1] # eqn 14.5.17
        u[:,j] = solve_toeplitz(toepk, rhs) # here is a linear system solver (hence an implicit method)
    # let's produce the x and t vectors, in case we need them
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    return u,x,t

# %% [markdown]
# ### Third example
# We do 1000 steps in time and space, using a triangular waveform for the initial values. We then call the implicit wave equation solver, which is supposed to be better. Finally, we set up Bokeh to plot the answers for us.

# %%
# Define the initial parameters, including a triangular waveform
c2 = .5  # velocity squared
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# solve with the implicit method
(u_imp,x,t)=w_solve2(c2,dx,dt,t_len,1*triangle,0*triangle)

# And now we plot the result

y=u_imp[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="FD Implicit method solution", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_imp(k=0):
    src.data['y']=u_imp[:,k]
    p.title="FD Implicit method solution"
    push_notebook()

show(p)
# Out:
# CFL value is  0.707106781187
#     <div class="plotdiv" id="f994dd1a-b8b1-4f9d-9dbc-79a6c03648f7"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f994dd1a-b8b1-4f9d-9dbc-79a6c03648f7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f994dd1a-b8b1-4f9d-9dbc-79a6c03648f7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"24453fcb-838d-4485-b9b5-5ae35baadf3b":{"roots":{"references":[{"attributes":{"plot":{"id":"cb93ef9e-c9c2-451a-8d5e-d0a6f6afd558","subtype":"Figure","type":"Plot"}},"id":"02eaef5b-7aef-4fd4-aa1a-4c977d1a1845","type":"PreviewSaveTool"},{"attributes":{"formatter":{"id":"5f65e66e-6ffd-47f8-b707-523a36322065","type":"BasicTickFormatter"},"plot":{"id":"263a0950-c52f-46cd-b70e-cee1226d45c3","subtype":"Figure","type":"Plot"},"ticker":{"id":"b01a0128-6f3b-4f78-8647-cc8493a893dd","type":"BasicTicker"}},"id":"5a29b877-6775-49e0-a8d0-6b73c7f62bab","type":"LinearAxis"},{"attributes":{},"id":"a65312d3-3a4d-4cfe-80aa-36b6b09c72d4","type":"ToolEvents"},{"attributes":{"overlay":{"id":"43eb3780-bb3b-4579-a3d7-b3907784f988","type":"BoxAnnotation"},"plot":{"id":"8aed5448-ac11-43af-ad57-6cbfd7ca740d","subtype":"Figure","type":"Plot"}},"id":"6040cb12-5084-4d49-b33c-2974d11b65b8","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"f67d0b4c-3f73-4a01-9144-9c65c28cb765","type":"BasicTickFormatter"},"plot":{"id":"62ac9f29-cbb5-479b-b85d-14ccc7648e02","subtype":"Figure","type":"Plot"},"ticker":{"id":"4cca30ab-7e3d-4337-ada0-927e848be3b7","type":"BasicTicker"}},"id":"b3e8f243-0370-4b73-8f77-9b6b8759936d","type":"LinearAxis"},{"attributes":{"plot":{"id":"83d7c858-92ea-42dd-aec2-8c10fcfa2f50","subtype":"Figure","type":"Plot"}},"id":"65a767a6-020e-4bb6-b632-953343fb5c99","type":"ResizeTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"da68dd23-7d3b-4b17-906c-e87a2eebc6be","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"b6e575cf-0494-4877-acbf-d9d15538b94e","type":"LinearAxis"}],"left":[{"id":"40383a16-4c9f-45aa-8936-93fe5c5b9a4e","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"b6e575cf-0494-4877-acbf-d9d15538b94e","type":"LinearAxis"},{"id":"773657ca-4ac9-4d07-956d-0c05149f8f13","type":"Grid"},{"id":"40383a16-4c9f-45aa-8936-93fe5c5b9a4e","type":"LinearAxis"},{"id":"2ad76ad7-c4c6-463f-83a1-7bf939b9960a","type":"Grid"},{"id":"eee9a34f-1377-4cdd-b71f-3acb425126fb","type":"BoxAnnotation"},{"id":"c3b59152-4797-40e2-84e4-bb3d5d6194f3","type":"GlyphRenderer"}],"title":"D'Alembert method, init velocity","tool_events":{"id":"b1912565-601c-4a82-b779-61411474c85d","type":"ToolEvents"},"tools":[{"id":"fce1a7db-5da0-4dfe-8628-45aa62435b29","type":"PanTool"},{"id":"695da9d7-6404-48aa-869b-b1445e371a29","type":"WheelZoomTool"},{"id":"dbd6857e-dd75-43ee-b92c-48fb9c2c77ca","type":"BoxZoomTool"},{"id":"02eaef5b-7aef-4fd4-aa1a-4c977d1a1845","type":"PreviewSaveTool"},{"id":"12b67199-3f09-472e-b60c-1ddbc4de7595","type":"ResizeTool"},{"id":"68d3816f-d583-40d4-b572-762de19c6d7b","type":"ResetTool"},{"id":"33e4781f-c35d-4d14-9ff8-a884346ac5e1","type":"HelpTool"}],"x_range":{"id":"c10fcdb7-2fba-498c-bb6c-831a1c3b241a","type":"DataRange1d"},"y_range":{"id":"9f243675-5366-4622-85da-6558529cec9e","type":"DataRange1d"}},"id":"cb93ef9e-c9c2-451a-8d5e-d0a6f6afd558","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"93cda3ab-6f8f-454d-86ba-0803d11f75e3","type":"BasicTicker"},{"attributes":{"below":[{"id":"4d723ddf-90e1-490a-959e-745412f9fd09","type":"LinearAxis"}],"left":[{"id":"5a29b877-6775-49e0-a8d0-6b73c7f62bab","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"4d723ddf-90e1-490a-959e-745412f9fd09","type":"LinearAxis"},{"id":"2b5cfbe0-e35c-4925-89ca-899bc04790d3","type":"Grid"},{"id":"5a29b877-6775-49e0-a8d0-6b73c7f62bab","type":"LinearAxis"},{"id":"eb7c3b61-97a4-47e4-b411-53a4b3c161e5","type":"Grid"},{"id":"d29828ad-72ba-45f4-8804-00c0febecab4","type":"BoxAnnotation"},{"id":"b26b32a5-ba17-45ac-8036-3f62d1c5c572","type":"GlyphRenderer"}],"title":"FD Explicit method solution","tool_events":{"id":"ba1d9b4e-a3ba-4d5f-8cb4-de7f8c733ba0","type":" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[32]</strong>&gt;</code></p>

# %%
interact(update_imp,k=(0,t_len-1))
# Out:
# <function __main__.update_imp>

# %% [markdown]
# ### Fourth example
# Derivative initial condition. Using the implicit solver, we solve for the initial particle velocity as a triangular waveform.

# %%
# Define the initial parameters, including a triangular waveform
c2 = .5  # velocity squared
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# Solve using the implicit solver. We do 3000 time steps to see what is going on. 
(u_impD,x,t)=w_solve2(c2,dx,dt,3*t_len,0*triangle,1*triangle)

# And now we plot the result

y=u_impD[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="FD Implicit method, init velocity", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_impD(k=0):
    src.data['y']=u_impD[:,k]
    p.title="FD Implicit method, init velocity"
    push_notebook()

show(p)
# Out:
# CFL value is  0.707106781187
#     <div class="plotdiv" id="7978cf3f-d74b-46ac-854f-75068cb83bf2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7978cf3f-d74b-46ac-854f-75068cb83bf2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7978cf3f-d74b-46ac-854f-75068cb83bf2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {
subtype":"Figure","type":"Plot"},{"attributes":{},"id":"93cda3ab-6f8f-454d-86ba-0803d11f75e3","type":"BasicTicker"},{"attributes":{"below":[{"id":"4d723ddf-90e1-490a-959e-745412f9fd09","type":"LinearAxis"}],"left":[{"id":"5a29b877-6775-49e0-a8d0-6b73c7f62bab","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"4d723ddf-90e1-490a-959e-745412f9fd09","type":"LinearAxis"},{"id":"2b5cfbe0-e35c-4925-89ca-899bc04790d3","type":"Grid"},{"id":"5a29b877-6775-49e0-a8d0-6b73c7f62bab","type":"LinearAxis"},{"id":"eb7c3b61-97a4-47e4-b411-53a4b3c161e5","type":"Grid"},{"id":"d29828ad-72ba-45f4-8804-00c0febecab4","type":"BoxAnnotation"},{"id":"b26b32a5-ba17-45ac-8036-3f62d1c5c572","type":"GlyphRenderer"}],"title":"FD Explicit method solution","tool_events":{"id":"ba1d9b4e-a3ba-4d5f-8cb4-de7f8c733ba0","type":"ToolEvents"},"tools":[{"id":"067a2801-5dd9-4799-b156-2d2723836c76","type":"PanTool"},{"id":"83a74b2c-cfb0-4f20-ab96-b9f23df54b6f","type":"WheelZoomTool"},{"id":"32ce979e-25fd-4153-8e3a-def36717a650","type":"BoxZoomTool"},{ ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[34]</strong>&gt;</code></p>

# %%
interact(update_impD,k=(0,3*t_len-1))
# Out:
# <function __main__.update_impD>

# %% [markdown]
# ## D'Alembert's solution
#
# Since the velocity $c$ is constant in these examples, we can get the exact solution via D'Alembert. The general solution will be of the form
# $$u(x,t) = \phi(x+ct) + \psi(x-ct). $$
# Initial conditions tell use that
# $$u(x,0) = \phi(x) + \psi(x) = f(x), $$ and
# $$u_t(x,0) = c\phi'(x) - c\psi'(x) = g(x). $$
# With $G(x)$ the antiderivative of $g(x)$ with appropriate zero at zero, we get a 2x2 system
# $$\phi(x) + \psi(x) = f(x), \\ c(\phi(x) - \psi(x)) = G(x),$$
# which we solve as
# $$\phi(x) = \frac{1}{2}\left( f(x) + \frac{1}{c} G(x) \right), \\
#   \psi(x) = \frac{1}{2}\left( f(x) - \frac{1}{c} G(x) \right).$$
#
# Now $f(x)$ is given as the argument $u0$ in the code. $G(x)$ can be computed using scipy. The arguments $x+ct$ and $x-ct$ must be converted to integer indices. They have to wrap around. And with the zero boundary condition, we need to wrap around with a negative reflection.
#
# There is the messy question as to whether we require $u(0,t)$ to actually equal zero, or do we require it to be zero one index "to the left" of x=0. Let's not think too much about that just yet.

# %%
# Based on D'Alembert's solution, as described above
def w_solve3(c2,dx,dt,t_len,u0,u1):
    x_len = np.size(u0)  # the length of u0 implicitly defines the num of points in x direction
    u = np.zeros((x_len,t_len),order='F') # output array initialized to zero 
    c = np.sqrt(c2)  # the actual velocity parameter is needed
    f = u0  # use notation from above notes
    G = cumtrapz(u1,dx=dx,initial=0) # the antiderivative, using cumulative trapezoidal rule
    f2 = np.append(f,-f[::-1]) # odd symmetry
    G2 = np.append(G,G[::-1]) # even symmetry
    phi2 = (f2 + G2/c)/2
    psi2 = (f2 - G2/c)/2
    x = np.linspace(0,dx*x_len,x_len,endpoint=False)
    t = np.linspace(0,dt*t_len,t_len,endpoint=False)
    # in the loop, we convert x+ct to index's into vectors phi2, psi2, modulo the vector length
    for j in range(t_len):
        ii1 = np.mod( np.round((x+c*t[j])/dx), 2*x_len)
        ii2 = np.mod( np.round((x-c*t[j])/dx), 2*x_len)
        u[:,j] = phi2[ii1.astype(int)] + psi2[ii2.astype(int)]
    return u,x,t

# %% [markdown]
# ### Fifth example
#
# We do 1000 steps in time and space, using a triangular waveform for the initial values.
# We then call the d'Alembert wave equation solver, which should be exact to machine precision.
# Finally, we set up Bokeh to plot the answers for us.

# %%
# Define the initial parameters, including a triangular waveform
c2 = .5  # velocity squared
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# solve using our d'Alembert solver
(u_dal,x,t)=w_solve3(c2,dx,dt,t_len,1*triangle,0*triangle)

# and now we plot

y=u_dal[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert solution", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_dal(k=0):
    src.data['y']=u_dal[:,k]
    p.title="D'Alembert solution"
    push_notebook()

show(p)
# Out:
#     <div class="plotdiv" id="c8479633-8922-450d-ac75-b866cbd6d716"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c8479633-8922-450d-ac75-b866cbd6d716");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c8479633-8922-450d-ac75-b866cbd6d716' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cd5f0ea2-3643-4d5c-b399-2c341c4afd3c":{"roots":{"references":[{"attributes":{"plot":{"id":"765d224a-fc83-465c-8c45-9f1c9d5646f1","subtype":"Figure","type":"Plot"}},"id":"79476239-05ea-4be5-94ed-b65c2dfc3200","type":"PreviewSaveTool"},{"attributes":{"plot":{"id":"765d224a-fc83-465c-8c45-9f1c9d5646f1","subtype":"Figure","type":"Plot"},"ticker":{"id":"75a32a51-1df3-4fe3-8ab1-05b4b6448a0a","type":"BasicTicker"}},"id":"59385df5-0da3-4013-a70f-31c252775093","type":"Grid"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"b584b9ac-c1cc-4b40-b8c0-da3a752d3b97","type":"Line"},{"attributes":{"plot":{"id":"765d224a-fc83-465c-8c45-9f1c9d5646f1","subtype":"Figure","type":"Plot"}},"id":"bf815486-5ea7-41c0-81ae-6d458f9b1274","type":"HelpTool"},{"attributes":{"below":[{"id":"5be2cfa9-bac4-4244-931e-ae927f151000","type":"LinearAxis"}],"left":[{"id":"c910b75d-89cb-4ef4-8808-c5801350382d","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"5be2cfa9-bac4-4244-931e-ae927f151000","type":"LinearAxis"},{"id":"6a7a65a4-6e27-445a-a2c8-9045537d899c","type":"Grid"},{"id":"c910b75d-89cb-4ef4-8808-c5801350382d","type":"LinearAxis"},{"id":"624aeb53-9005-47c2-86bb-140a119dc364","type":"Grid"},{"id":"0d1775ac-8e4b-435f-bd88-c12ffef0e22c","type":"BoxAnnotation"},{"id":"2d1fe055-358b-4a91-8ae4-9a9762087e60","type":"GlyphRenderer"}],"title":"FD Explicit method solution","tool_events":{"id":"3562c652-285d-435c-a579-074aa43e4690","type":"ToolEvents"},"tools":[{"id":"ca0646f8-39c7-4f06-af44-22e2fe64d6b8","type":"PanTool"},{"id":"a8ec17f3-475e-4133-a513-432d9188d2b2","type":"WheelZoomTool"},{"id":"aeaf2c15-3210-4eed-9b76-eb012d20ad77","type":"BoxZoomTool"},{"id":"7ee3a101-4ff0-4047-8232-7625a604ee8e","type":"PreviewSaveTool"},{"id":"14760bb5-51fa-44f9-8765-f09e65f33ac0","type":"ResizeTool"},{"id":"93d06beb-de03-4a24-8c0b-819b5fe9517e","type":"ResetTool"},{"id":"ecec5e2d-7486-483d-8a97-4fb637912d11","type":"HelpTool"}],"x_range":{"id":"32b144c8-93f0-4717-818c-4efebef54886","type":"DataRange1d"},"y_range":{"id":"f366eccb-7a9d-45fc-9c52-22f47b7157fc","type":"DataRange1d"}},"id":"fa8a7a93-6c7a-44cf-8f1c-be0f7107b488","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"850acc19-ac98-4c66-b860-0c4d8a37d33e","subtype":"Figure","type":"Plot"}},"id":"812fe520-5b29-4224-9c0a-3f452a552069","type":"PreviewSaveTool"},{"attributes":{"formatter":{"id":"426023c6-5c0c-49ec-a189-c8f6d77537f2","type":"BasicTickFormatter"},"plot":{"id":"850acc19-ac98-4c66-b860-0c4d8a37d33e","subtype":"Figure","type":"Plot"},"ticker":{"id":"79a82174-f6d6-41be-a198-3e4b485cf4c9","type":"BasicTicker"}},"id":"04357017-a686-4f75-b979-e662499b542f","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7f6a0971-01b1-498a-9cdf-e05eb313ebf4","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y","x","y"],"data":{"x":[0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009000000000000001,0.01,0.011,0.012,0.013000000000000001,0.014,0.015,0.016,0.017,0.018000000000000002,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026000000000000002,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036000000000000004,0.037,0.038,0.039,0.04,0.041,0.042,0.043000000000000003,0.044,0.045,0.046,0.047,0.048,0.049,0.05,0.051000000000000004,0.052000000000000005,0.053,0.054,0.055,0.056,0.057,0.058,0.059000000000000004,0.06,0.061,0.062,0.063,0.064,0.065,0.066,0.067,0.068,0.069,0.07,0.07100000000000001,0.07200000000000001,0.073,0.074,0.075,0.076,0.077,0.078,0.079,0.08,0.081,0.082,0.083,0.084,0.085,0.08600000000000001,0.08700000000000001,0.088,0.089,0.09,0.091,0.092,0.093,0.094,0.095,0.096,0.097,0.098,0.099,0.1,0.101,0.10200000000000001,0.10300000000000001,0.10400000000000001,0.105,0.106,0.107,0.108,0.109,0.11,0.111,0.112,0.113,0.114,0.115,0.116,0.117,0.11800000000000001,0.11900000000000001,0.12,0.121,0.122,0.123,0.124,0.125,0. ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %%
interact(update_dal,k=(0,t_len-1))

# %% [markdown]
# ### Sixth example
# Derivative initial condition. Using the exact solver, we solve for the initial particle velocity as a triangular waveform. Derivative initial condition.

# %%
# Define the initial parameters, including a triangular waveform
c2 = .5  # velocity squared
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
triangle = np.maximum(0.,.1-np.absolute(x-.4))

# solve using our d'Alembert solver. We do 3000 time steps, to see what is going on.
(u_dalD,x,t)=w_solve3(c2,dx,dt,3*t_len,0*triangle,1*triangle)

# And now we plot the result

y=u_dalD[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alembert method, init velocity", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_dalD(k=0):
    src.data['y']=u_dalD[:,k]
    p.title="D'Alembert method, init velocity"
    push_notebook()

show(p)
# Out:
#     <div class="plotdiv" id="6ee28438-8e63-40e1-8d20-7223e77dd578"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6ee28438-8e63-40e1-8d20-7223e77dd578");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6ee28438-8e63-40e1-8d20-7223e77dd578' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e30392b6-31a5-4cb1-87f4-8a950ea80274":{"roots":{"references":[{"attributes":{"plot":{"id":"cb93ef9e-c9c2-451a-8d5e-d0a6f6afd558","subtype":"Figure","type":"Plot"}},"id":"02eaef5b-7aef-4fd4-aa1a-4c977d1a1845","type":"PreviewSaveTool"},{"attributes":{"formatter":{"id":"5f65e66e-6ffd-47f8-b707-523a36322065","type":"BasicTickFormatter"},"plot":{"id":"263a0950-c52f-46cd-b70e-cee1226d45c3","subtype":"Figure","type":"Plot"},"ticker":{"id":"b01a0128-6f3b-4f78-8647-cc8493a893dd","type":"BasicTicker"}},"id":"5a29b877-6775-49e0-a8d0-6b73c7f62bab","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"2a8437c6-a7a4-484c-b79a-e3a3dd00ef13","type":"Line"},{"attributes":{},"id":"a65312d3-3a4d-4cfe-80aa-36b6b09c72d4","type":"ToolEvents"},{"attributes":{"overlay":{"id":"43eb3780-bb3b-4579-a3d7-b3907784f988","type":"BoxAnnotation"},"plot":{"id":"8aed5448-ac11-43af-ad57-6cbfd7ca740d","subtype":"Figure","type":"Plot"}},"id":"6040cb12-5084-4d49-b33c-2974d11b65b8","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"f67d0b4c-3f73-4a01-9144-9c65c28cb765","type":"BasicTickFormatter"},"plot":{"id":"62ac9f29-cbb5-479b-b85d-14ccc7648e02","subtype":"Figure","type":"Plot"},"ticker":{"id":"4cca30ab-7e3d-4337-ada0-927e848be3b7","type":"BasicTicker"}},"id":"b3e8f243-0370-4b73-8f77-9b6b8759936d","type":"LinearAxis"},{"attributes":{"plot":{"id":"83d7c858-92ea-42dd-aec2-8c10fcfa2f50","subtype":"Figure","type":"Plot"}},"id":"65a767a6-020e-4bb6-b632-953343fb5c99","type":"ResizeTool"},{"attributes":{"plot":{"id":"6066d258-f309-45e0-8e1e-72eed8c53c96","subtype":"Figure","type":"Plot"}},"id":"a7440c31-df06-41d1-808b-349acd37d480","type":"HelpTool"},{"attributes":{"below":[{"id":"b6e575cf-0494-4877-acbf-d9d15538b94e","type":"LinearAxis"}],"left":[{"id":"40383a16-4c9f-45aa-8936-93fe5c5b9a4e","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"b6e575cf-0494-4877-acbf-d9d15538b94e","type":"LinearAxis"},{"id":"773657ca-4ac9-4d07-956d-0c05149f8f13","type":"Grid"},{"id":"40383a16-4c9f-45aa-8936-93fe5c5b9a4e","type":"LinearAxis"},{"id":"2ad76ad7-c4c6-463f-83a1-7bf939b9960a","type":"Grid"},{"id":"eee9a34f-1377-4cdd-b71f-3acb425126fb","type":"BoxAnnotation"},{"id":"c3b59152-4797-40e2-84e4-bb3d5d6194f3","type":"GlyphRenderer"}],"title":"D'Alembert method, init velocity","tool_events":{"id":"b1912565-601c-4a82-b779-61411474c85d","type":"ToolEvents"},"tools":[{"id":"fce1a7db-5da0-4dfe-8628-45aa62435b29","type":"PanTool"},{"id":"695da9d7-6404-48aa-869b-b1445e371a29","type":"WheelZoomTool"},{"id":"dbd6857e-dd75-43ee-b92c-48fb9c2c77ca","type":"BoxZoomTool"},{"id":"02eaef5b-7aef-4fd4-aa1a-4c977d1a1845","type":"PreviewSaveTool"},{"id":"12b67199-3f09-472e-b60c-1ddbc4de7595","type":"ResizeTool"},{"id":"68d3816f-d583-40d4-b572-762de19c6d7b","type":"ResetTool"},{"id":"33e4781f-c35d-4d14-9ff8-a884346ac5e1","type":"HelpTool"}],"x_range":{"id":"c10fcdb7-2fba-498c-bb6c-831a1c3b241a","type":"DataRange1d"},"y_range":{"id":"9f243675-5366-4622-85da-6558529cec9e","type":"DataRange1d"}},"id":"cb93ef9e-c9c2-451a-8d5e-d0a6f6afd558","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"93cda3ab-6f8f-454d-86ba-0803d11f75e3","type":"BasicTicker"},{"attributes":{"below":[{"id":"4d723ddf-90e1-490a-959e-745412f9fd09","type":"LinearAxis"}],"left":[{"id":"5a29b877-6775-49e0-a8d0-6b73c7f62bab","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"4d723ddf-90e1-490a-959e-745412f9fd09","type":"LinearAxis"},{"id":"2b5cfbe0-e35c-4925-89ca-899bc04790d3","type":"Grid"},{"id":"5a29b877-6775-49e0-a8d0-6b73c7f62bab","type":"LinearAxis"},{"id":"eb7c3b61-97a4-47e4-b411-53a4b3c161e5","type":"Grid"},{"id":"d29828ad-72ba-45f4-8804-00c0febecab4","type":"BoxAnnotation"},{"id":"b26b32a5-ba17-45ac-8036-3f62d1c5c572","type":"GlyphRenderer"}],"title":"FD Explicit method solution","tool_events":{"id":"ba1d9b4e-a3ba-4d5f-8cb4-de7f8c733ba0","type":"ToolEvents"},"tools":[{"id":"067a2801-5dd9-4799-b156- ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[39]</strong>&gt;</code></p>

# %%
interact(update_dalD,k=(0,3*t_len-1))
# Out:
# <function __main__.update_dalD>

# %% [markdown]
# # Comparing solutions
#
# ### Seventh example
#
# In principle, we want these different solution methods to be directly comparable.
#
# So let's try this out, by computing the difference of two solution.
#
# Here we compare the explicit f.d. method with d'Alambert's method.

# %%
# If you want, you can re-compute these. But we did it above already.
#(u_exp,x,t)=w_solve1(.5,dx,dt,t_len,1*triangle,0*triangle)
#(u_dal,x,t)=w_solve3(.5,dx,dt,t_len,1*triangle,0*triangle)

y=u_dal[:,0]-u_exp[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))

p = figure(title="D'Alemb
},{"attributes":{"plot":{"id":"6066d258-f309-45e0-8e1e-72eed8c53c96","subtype":"Figure","type":"Plot"}},"id":"2fb0e5fe-e722-4d12-845a-ccd6cdf407a8","type":"ResetTool"},{"attributes":{"plot":{"id":"0f958 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[41]</strong>&gt;</code></p>

# %%
interact(update_comp,k=(0,t_len-1))
# Out:
# <function __main__.update_comp>

# %% [markdown]
# # A moving wavefront
#
# ### Example eight
#
# Let's try an actual wave. We want something like
# $$u(x,t) = \exp(-(x -x_a-ct)^2/w^2), $$
# where $x_a$ is the center of the Gaussian at $t=0$, $w$ is the width of the Gaussian, $c$ is the velocity of the wave.
#
# This gives
# $$u_0(x) = \exp(-(x -x_a)^2/w^2) \\
#   u_1(x) = \frac{2c(x-x_a)}{w^2}\exp(-(x -x_a)^2/w^2) = \frac{2c(x-x_a)}{w^2}u_0(x).$$

# %%
# We set up the initial waveform corresponding to a Gaussian moving to the right.
# The value of velocity c is very important here!
c = .707  # velocity
x_len = 1000
t_len = 1000
dx = 1./x_len
dt = 1./t_len
x = np.linspace(0,1,x_len)
t = np.linspace(0,1,t_len)
u0 = np.exp(-(x-.5)*(x-.5)/.01)
u1 = 2*c*u0*(x-.5)/.01

# now we solve using the d'Alembert solution. We do 3000 steps, though!

(u_wav,x,t)=w_solve3(c*c,dx,dt,3*t_len,u0,u1)  # notice we input the velocity squared!

# And now we plot

y=u_wav[:,0]
src = ColumnDataSource(data=dict(x=x,y=y))
p = figure(title="Moving wave", plot_height=300, plot_width=600)
p.line(x,y,color="#2222aa",line_width=3,source=src,name="foo")

def update_wav(k=0):
    src.data['y']=u_wav[:,k]
    p.title="Moving wave"
    push_notebook()
    
show(p)
# Out:
#     <div class="plotdiv" id="6406ad19-0da1-4bee-ae3b-62a613ff2aad"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6406ad19-0da1-4bee-ae3b-62a613ff2aad");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6406ad19-0da1-4bee-ae3b-62a613ff2aad' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"37ff10fc-f47d-4dee-adc7-23d2f2458bba":{"roots":{"references":[{"attributes":{},"id":"a65312d3-3a4d-4cfe-80aa-36b6b09c72d4","type":"ToolEvents"},{"attributes":{"overlay":{"id":"43eb3780-bb3b-4579-a3d7-b3907784f988","type":"BoxAnnotation"},"plot":{"id":"8aed5448-ac11-43af-ad57-6cbfd7ca740d","subtype":"Figure","type":"Plot"}},"id":"6040cb12-5084-4d49-b33c-2974d11b65b8","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"6066d258-f309-45e0-8e1e-72eed8c53c96","subtype":"Figure","type":"Plot"}},"id":"a7440c31-df06-41d1-808b-349acd37d480","type":"HelpTool"},{"attributes":{},"id":"012a04d9-752a-43c4-bf5f-e323fbb44e80","type":"BasicTicker"},{"attributes":{},"id":"544a1ca3-4175-40b7-944a-28c57992bc53","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c0421f0c-7951-4eb7-ba35-5df578a4e08b","subtype":"Figure","type":"Plot"}},"id":"f8099616-4cce-4d31-b7fa-d685f07aa0ff","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"cb9da8c9-29d9-4998-80c0-df259f1bc0ee","subtype":"Figure","type":"Plot"},"ticker":{"id":"fbcca7a9-f32f-41c7-9dd9-8b17f877cc51","type":"BasicTicker"}},"id":"5939ac83-cdec-41a6-b65a-ee2a769ca463","type":"Grid"},{"attributes":{"overlay":{"id":"5045f262-b794-4794-ab74-395ba28bd6ee","type":"BoxAnnotation"},"plot":{"id":"83d7c858-92ea-42dd-aec2-8c10fcfa2f50","subtype":"Figure","type":"Plot"}},"id":"afbd5a86-1cda-45eb-af97-fcc61b587de8","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"c62d0eb2-ab53-4ec8-8b8b-b4c9e5fb2c71","subtype":"Figure","type":"Plot"}},"id":"94c4f428-bbdf-490a-aca9-c2ff3bee5238","type":"PanTool"},{"attributes":{},"id":"f60b6fc1-96f9-4b78-a130-1741a50ff2cf","type":"ToolEvents"},{"attributes":{"callback":null},"id":"5df9e022-e308-4cce-bf79-711541dff18a","type":"DataRange1d"},{"attributes":{"plot":{"id":"1fd20945-91cc-49d6-b29e-2ef9e4d4791f","subtype":"Figure","type":"Plot"}},"id":"a768569a-b169-43c8-9135-10f5274f1e6f","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e469aaad-56b2-4a03-b2e1-2f61938c29e1","type":"BoxAnnotation"},{"attributes":{},"id":"859caf2d-15db-48a6-96ed-89905a1e2906","type":"ToolEvents"},{"attributes":{},"id":"2884666f-fab1-4e28-9527-70a070b6d211","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1b4dd8d-7b53-449d-a022-bf9b285b91d8","type":"Line"},{"attributes":{"data_source":{"id":"5fa0a550-ddbd-4842-a8b8-f94f281bcdc8","type":"ColumnDataSource"},"glyph":{"id":"41bf57d9-3a1e-4940-8a97-4734aa7b833a","type":"Line"},"hover_glyph":null,"name":"foo","nonselection_glyph":{"id":"4e23dfe5-6136-43ce-83da-442b81ce3a84","type":"Line"},"selection_glyph":null},"id":"f9364b70-abbd-46b7-8e86-23b2bc6d7abb","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"6066d258-f309-45e0-8e1e-72eed8c53c96","subtype":"Figure","type":"Plot"}},"id":"a3abd7f1-fbc9-4aa9-a2eb-bdf890facde6","type":"PreviewSaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8713684f-6acb-4757-a5fb-5ed44e56c4fa","type":"BoxAnnotation"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"d5ae0c76-d9a6-43e6-b5b1-e3acd97a3495","type":"Line"},{"attributes":{},"id":"6e13c84d-116b-496c-bb72-3555a81a59ee","type":"BasicTicker"},{"attributes":{"callback":null},"id":"eb704ed5-0423-4980-bddc-aef8401678cf","type":"DataRange1d"},{"attributes":{"callback":null},"id":"e3db770f-f569-4a ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[43]</strong>&gt;</code></p>

# %%
interact(update_wav,k=(0,3*t_len-1))
# Out:
# <function __main__.update_wav>

# %% [markdown]
# # Summary
#
# Here are all the animated waves, put together with controls for a convenient demo.

# %%
interact(update_exp,k=IntSlider(min=0,max=t_len-1,description='Finite Diff, Explicit, init position'))
interact(update_expD,k=IntSlider(min=0,max=3*t_len-1,description='Finite Diff, Explicit, init velocity'))
interact(update_imp,k=IntSlider(min=0,max=t_len-1,description='Finite Diff, Implicit, init position'))
interact(update_impD,k=IntSlider(min=0,max=3*t_len-1,description='Finite Diff, Implicit, init velocity'))
interact(update_dal,k=IntSlider(min=0,max=t_len-1,description="d'Alembert, init position"))
interact(update_dalD,k=IntSlider(min=0,max=3*t_len-1,description="d'Alembert, init velocity"))
interact(update_comp,k=IntSlider(min=0,max=t_len-1,description='Comparison, exact minus F.D.'))
interact(update_wav,k=IntSlider(min=0,max=3*t_len-1,description='Moving wave (exact)'))

# %%
show(p)
# Out:
#     <div class="plotdiv" id="25abee14-5bf8-4104-a7f3-fc1f388cd62a"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("25abee14-5bf8-4104-a7f3-fc1f388cd62a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '25abee14-5bf8-4104-a7f3-fc1f388cd62a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"